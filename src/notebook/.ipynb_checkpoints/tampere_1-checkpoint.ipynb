# %%
import os
import random
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pickle

import torch
from torch.utils.data import DataLoader

import sys 

sys.path.insert(1, 'D:/IPS_PCA_CLUSTERING-the_end/')

from copy import deepcopy
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA, KernelPCA
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor

# custom
from src.utils.dataset import RSSIDataset
from src.utils.file_utils import read_data, load_data, load_csv
from src.utils.helper import get_current_date, normalize_data, separates_data_uts, mean_error, clip_gradient, \
    constant_columns, detect_num_feature_rssi, load_data_npz, draw_distribution_cluster, draw_kmean_distortion, \
    draw_kmean_silhouette, set_seed_everything
from src.utils.models import RegressionNet, ClassificationNet, Ensemble_Model, Ensemble_Classic_Model, train_regression, \
    train_classification, model_evaluation, classic_model_evaluation, load_model_classification, save_model_sklearn, \
    load_model_sklearn
from src.utils.loss import MeanLoss
import src.utils.regr_utils as regr

# %% [markdown]
# ### Global config

# %%
N_CLUSTER = 2
NUM_IN = 75
NUM_FEATURES_RSSI = 589
SEED = 2023
N_CPU = os.cpu_count()
set_seed_everything(SEED)

names = [
    "Nearest Neighbors",
    "Linear SVM",
    "RBF SVM",
    # "Gaussian Process",
    "Decision Tree",
    "Random Forest",
    "Neural Net",
    "AdaBoost",
    "Naive Bayes",
    "QDA",
]

date_str = get_current_date()
# date_str = "2023_02_05"
data_type_str = "tampere"
n_cluster_str = N_CLUSTER
model_path = {
    'type': 'kernel_pca_75 | TAMPERE | 2_cluster_label',
    'n_clusters': N_CLUSTER,
    'cluster': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_cluster.sav',
    'cluster_classifier': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_cluster_classifier.sav',
    'custom_cluster_classifier': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_custom_cluster_classifier.pth',
    'floor_classifier': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_floor_classifier.sav',
    'ensemble': f"../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/ensemble_model",
    "total": f"../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_total.pth",
}
Path(f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/').mkdir(parents=True, exist_ok=True)
Path(f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/ensemble_model').mkdir(parents=True,
                                                                                                     exist_ok=True)
regr_models = [
    DecisionTreeRegressor(),
    AdaBoostRegressor(),
    GradientBoostingRegressor(),
    XGBRegressor(),
    KNeighborsRegressor(),
    MLPRegressor(),
    SVR(),
]

# %% [markdown]
# ### Data Path

# %%
data_dir = f"../../data/{data_type_str}_data/pca/kernal_pca_cosine_{NUM_IN}/"
# data_dir = f"../../data/{data_type_str}_data/pca/pca_090"

(X_train, Y_train), (X_test, Y_test), (X_valid, Y_valid) = load_data_npz(
    [
        os.path.join(data_dir, "X_train.npz"),
        os.path.join(data_dir, "Y_train.npz"),
        os.path.join(data_dir, "X_test.npz"),
        os.path.join(data_dir, "Y_test.npz"),
        os.path.join(data_dir, "X_valid.npz"),
        os.path.join(data_dir, "Y_valid.npz")
    ]
)

# %%
X_train.shape
# Out:
# (627, 75)

# %% [markdown]
# ### K-Means Clustering

# %%
cluster = KMeans(n_clusters=N_CLUSTER).fit(Y_train[:, :2])
save_model_sklearn(model_path=model_path["cluster"], model=cluster)

Z_train = cluster.labels_
Z_test = cluster.predict(Y_test[:, :2])
Z_valid = cluster.predict(Y_valid[:, :2])

for i in np.unique(Z_valid):
    print(f"cluster valid {i}", len(Z_valid[Z_valid == i]))

for i in np.unique(Z_train):
    print(f"cluster train {i}", len(Z_train[Z_train == i]))

for i in np.unique(Z_test):
    print(f"cluster test {i}", len(Z_test[Z_test == i]))
# Out:
# ===== Save model sklearn successfully =====
# cluster valid 0 27
# cluster valid 1 43
# cluster train 0 288
# cluster train 1 339
# cluster test 0 1797
# cluster test 1 2154

# %% [markdown]
# ### Đồ thị clustering

# %%
# phân bố dữ liệu theo cluster của label
draw_distribution_cluster(Y_train[:, :2], Z_train, title="Y_TRAIN")
draw_distribution_cluster(Y_test[:, :2], Z_test, title="Y_TEST")
draw_distribution_cluster(Y_valid[:, :2], Z_valid, title="Y_VALID")

# %%
draw_kmean_distortion(Y_train[:, :2], range(1, 10))
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
draw_kmean_silhouette(Y_train[:, :2], [2, 3, 4, 5])

# %%
# regression dataset
train_regression_data = RSSIDataset(X_train, Y_train[:, :2])
valid_regression_data = RSSIDataset(X_valid, Y_valid[:, :2])
test_regression_data = RSSIDataset(X_test, Y_test[:, :2])

train_regression_dataloader = DataLoader(train_regression_data, batch_size=16, num_workers=N_CPU, pin_memory=True, drop_last=True)
valid_regression_dataloader = DataLoader(valid_regression_data, batch_size=1, pin_memory=True)
test_regression_dataloader = DataLoader(test_regression_data, batch_size=1, pin_memory=True)

# classifier dataset
train_cluster_dataset = RSSIDataset(X_train, Z_train)
valid_cluster_dataset = RSSIDataset(X_valid, Z_valid)
test_cluster_dataset = RSSIDataset(X_test, Z_test)

train_cluster_loader = DataLoader(train_cluster_dataset, batch_size=16, num_workers=N_CPU, drop_last=True)
valid_cluster_loader = DataLoader(valid_cluster_dataset, batch_size=1)
test_cluster_loader = DataLoader(test_cluster_dataset, batch_size=1)

# %% [markdown]
# ### Train and validate classification models

# %%
clf1 = GaussianNB()
clf2 = MLPClassifier()
clf3 = SVC(kernel='rbf', probability=True)

eclf = VotingClassifier(
    estimators=[
        ('clf1', clf1), ('clf2', clf2), ('clf3', clf3)
    ],
    voting="soft",
    weights=[3, 1, 2]
)

print(f"Train clf1 model: {clf1.__class__.__name__}")
clf1 = clf1.fit(X_train, Z_train)
print(f"Train clf2 model: {clf2.__class__.__name__}")
clf2 = clf2.fit(X_train, Z_train)
print(f"Train clf3 model: {clf3.__class__.__name__}")
clf3 = clf3.fit(X_train, Z_train)
print(f"Train eclf model: {eclf.__class__.__name__}")
eclf = eclf.fit(X_train, Z_train)

print(clf1.score(X_test, Z_test))
print(clf2.score(X_test, Z_test))
print(clf3.score(X_test, Z_test))
print(eclf.score(X_test, Z_test))

save_model_sklearn(model_path["cluster_classifier"], eclf)
# Out:
# Train clf1 model: GaussianNB
# Train clf2 model: MLPClassifier
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Train clf3 model: SVC
# Train eclf model: VotingClassifier
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.8658567451278157
# 0.9622880283472539
# 0.9554543153631991
# 0.9276132624651987
# ===== Save model sklearn successfully =====

# %%
loaded_model = load_model_sklearn(model_path["cluster_classifier"])
result = loaded_model.score(X_test, Z_test)
print("\nFinal")
print(result)
# Out:
# ===== Load model sklearn successfully =====
#
# Final
# 0.9276132624651987

# %% [markdown]
# ### Train custom cluster classifier

# %%
# net = ClassificationNet(num_in=NUM_IN, num_out=2)
#
# weight_path = model_path["custom_cluster_classifier"]
# train_classification(
#     net,
#     X_train,
#     Z_train,
#     X_valid,
#     Z_valid,
#     weight_path)

# %%
# weight_path = model_path["custom_cluster_classifier"]
# net = load_model_classification(weight_path, num_in=100, num_out=2)
# net.score(X_test, Z_test)

# %% [markdown]
# ### Train Ensemble

# %%
# train model cluster
ens_model = Ensemble_Model(n_cluster=N_CLUSTER, num_in=NUM_IN, ensemble_model_path=model_path["ensemble"])
ens_model.train_student(X_train, Y_train[:,:2], Z_train, X_valid, Y_valid[:,:2], Z_valid)

# classic
# ens_model = Ensemble_Classic_Model(models=regr_models, ensemble_model_path=model_path["ensemble"])
# ens_model.train_student(X_train, Y_train[:, :2], Z_train, X_valid, Y_valid[:, :2], Z_valid)
# Out:
#  ========== Training cluster 0 with dataset contain 288 train samples and 27 valid samples ==========
# Epoch 1 train: 100%|██████████████████████████████████| 18/18 [00:00<00:00, 110.34batch/s, AVG_LOSS=73, LOSS_ITER=78.1]
# Epoch 1 val: 100%|██████████████████████████████████| 27/27 [00:00<00:00, 463.89batch/s, AVG_LOSS=61.4, LOSS_ITER=61.5]
#                                                                                                      Best valid loss: 61.3574
# Epoch 2 train: 100%|████████████████████████████████| 18/18 [00:00<00:00, 124.02batch/s, AVG_LOSS=68.8, LOSS_ITER=63.1]
# Epoch 2 val: 100%|██████████████████████████████████| 27/27 [00:00<00:00, 415.16batch/s, AVG_LOSS=40.7, LOSS_ITER=41.1]
#                                                                                                      Best valid loss: 40.6818
# Epoch 3 train: 100%|████████████████████████████████| 18/18 [00:00<00:00, 131.03batch/s, AVG_LOSS=28.8, LOSS_ITER=21.2]
# Epoch 3 val: 100%|██████████████████████████████████| 27/27 [00:00<00:00, 369.74batch/s, AVG_LOSS=41.7, LOSS_ITER=39.2]
# Epoch 4 train: 100%|████████████████████████████████| 18/18 [00:00<00:00, 123.52batch/s, AVG_LOSS=17.6, LOSS_ITER=20.2]
# Epoch 4 val: 100%|████████████████████████████████████| 27/27 [00:00<00:00, 369.57batch/s, AVG_LOSS=25.4, LOSS_ITER=24]
#                                                                                                      Best valid loss: 25.4172
# Epoch 5 train: 100%|██████████████████████████████████| 18/18 [00:00<00:00, 115.09batch/s, AVG_LOSS=16, LOSS_ITER=16.4]
# Epoch 5 val: 100%|██████████████████████████████████| 27/27 [00:00<00:00, 463.61batch/s, AVG_LOSS=28.6, LOSS_ITER=20.9]
# Epoch 6 train: 100%|██████████████████████████████████| 18/18 [00:00<00:00, 131.94batch/s, AVG_LOSS=15.1, LOSS_ITER=17]
# Epoch 6 val: 100%|██████████████████████████████████| 27/27 [00:00<00:00, 417.69batch/s, AVG_LOSS=31.1, LOSS_ITER=38.6]
# Epoch 7 train: 100%|██████████████████████████████████| 18/18 [00:00<00:00, 128.44batch/s, AVG_LOSS=13, LOSS_ITER=14.4]
# Epoch 7 val: 100%|███████████████████████████████████| 27/27 [00:00<00:00, 448.41batch/s, AVG_LOSS=24.7, LOSS_ITER=7.1]
#                                                                                                      Best valid loss: 24.6526
# Epoch 8 train: 100%|██████████████████████████████████| 18/18 [00:00<00:00, 125.62batch/s, AVG_LOSS=11, LOSS_ITER=10.2]
# Epoch 8 val: 100%|██████████████████████████████████| 27/27 [00:00<00:00, 402.42batch/s, AVG_LOSS=39.3, LOSS_ITER=38.4]
# Epoch 9 train: 100%|████████████████████████████████| 18/18 [00:00<00:00, 133.10batch/s, AVG_LOSS=10.1, LOSS_ITER=7.24]
# Epoch 9 val: 100%|██████████████████████████████████| 27/27 [00:00<00:00, 433.23batch/s, AVG_LOSS=24.1, LOSS_ITER=2.63]
#                                                                                                      Best valid loss: 24.1428
# Epoch 10 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 126.30batch/s, AVG_LOSS=9.45, LOSS_ITER=6.07]
# Epoch 10 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 460.44batch/s, AVG_LOSS=25.7, LOSS_ITER=13.3]
# Epoch 11 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 131.69batch/s, AVG_LOSS=8.76, LOSS_ITER=8.95]
# Epoch 11 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 444.23batch/s, AVG_LOSS=27.5, LOSS_ITER=13.4]
# Epoch 12 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 136.01batch/s, AVG_LOSS=8.49, LOSS_ITER=8.48]
# Epoch 12 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 476.69batch/s, AVG_LOSS=26.8, LOSS_ITER=26.3]
# Epoch 13 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 128.41batch/s, AVG_LOSS=8.25, LOSS_ITER=6.41]
# Epoch 13 val: 100%|███████████████████████████████████| 27/27 [00:00<00:00, 423.86batch/s, AVG_LOSS=36, LOSS_ITER=36.3]
# Epoch 14 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 131.65batch/s, AVG_LOSS=7.77, LOSS_ITER=9.74]
# Epoch 14 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 434.45batch/s, AVG_LOSS=29.9, LOSS_ITER=13.9]
# Epoch 15 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 126.91batch/s, AVG_LOSS=7.27, LOSS_ITER=5.18]
# Epoch 15 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 463.85batch/s, AVG_LOSS=31.3, LOSS_ITER=23.6]
# Epoch 16 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 135.77batch/s, AVG_LOSS=7.17, LOSS_ITER=6.98]
# Epoch 16 val: 100%|██████████████████████████████████| 27/27 [00:00<00:00, 450.32batch/s, AVG_LOSS=21.6, LOSS_ITER=7.2]
#                                                                                                      Best valid loss: 21.5827
# Epoch 17 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 146.95batch/s, AVG_LOSS=7.21, LOSS_ITER=8.81]
# Epoch 17 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 423.76batch/s, AVG_LOSS=24.7, LOSS_ITER=14.8]
# Epoch 18 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 122.28batch/s, AVG_LOSS=6.71, LOSS_ITER=7.96]
# Epoch 18 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 465.29batch/s, AVG_LOSS=21.6, LOSS_ITER=6.47]
# Epoch 19 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 134.43batch/s, AVG_LOSS=6.72, LOSS_ITER=9.81]
# Epoch 19 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 449.13batch/s, AVG_LOSS=22.3, LOSS_ITER=8.67]
# Epoch 20 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 127.48batch/s, AVG_LOSS=6.47, LOSS_ITER=7.18]
# Epoch 20 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 435.07batch/s, AVG_LOSS=28.6, LOSS_ITER=22.2]
# Epoch 21 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 141.65batch/s, AVG_LOSS=6.38, LOSS_ITER=3.96]
# Epoch 21 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 441.50batch/s, AVG_LOSS=34.4, LOSS_ITER=34.8]
# Epoch 22 train: 100%|█████████████████████████████████| 18/18 [00:00<00:00, 132.33batch/s, AVG_LOSS=6.2, LOSS_ITER=9.1]
# Epoch 22 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 414.93batch/s, AVG_LOSS=29.5, LOSS_ITER=30.1]
# Epoch 23 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 141.21batch/s, AVG_LOSS=5.97, LOSS_ITER=5.12]
# Epoch 23 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 407.53batch/s, AVG_LOSS=35.6, LOSS_ITER=34.8]
# Epoch 24 train: 100%|████████████████████████████████| 18/18 [00:00<00:00, 124.84batch/s, AVG_LOSS=5.9, LOSS_ITER=9.66]
# Epoch 24 val: 100%|███████████████████████████████████| 27/27 [00:00<00:00, 415.83batch/s, AVG_LOSS=36.9, LOSS_ITER=44]
# Epoch 25 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 118.20batch/s, AVG_LOSS=5.92, LOSS_ITER=6.52]
# Epoch 25 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 357.85batch/s, AVG_LOSS=24.5, LOSS_ITER=14.6]
# Epoch 26 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 119.23batch/s, AVG_LOSS=5.75, LOSS_ITER=7.16]
# Epoch 26 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 429.69batch/s, AVG_LOSS=40.9, LOSS_ITER=29.7]
# Epoch 27 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 138.56batch/s, AVG_LOSS=5.51, LOSS_ITER=6.35]
# Epoch 27 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 471.16batch/s, AVG_LOSS=25.6, LOSS_ITER=25.5]
# Epoch 28 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 142.04batch/s, AVG_LOSS=5.63, LOSS_ITER=6.49]
# Epoch 28 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 459.54batch/s, AVG_LOSS=23.6, LOSS_ITER=8.12]
# Epoch 29 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 124.39batch/s, AVG_LOSS=5.45, LOSS_ITER=6.67]
# Epoch 29 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 383.70batch/s, AVG_LOSS=22.4, LOSS_ITER=13.7]
# Epoch 30 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 128.61batch/s, AVG_LOSS=5.27, LOSS_ITER=6.58]
# Epoch 30 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 509.76batch/s, AVG_LOSS=41.9, LOSS_ITER=26.9]
# Epoch 31 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 145.66batch/s, AVG_LOSS=5.05, LOSS_ITER=3.44]
# Epoch 31 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 442.12batch/s, AVG_LOSS=24.7, LOSS_ITER=25.9]
# Epoch 32 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 127.76batch/s, AVG_LOSS=5.05, LOSS_ITER=5.26]
# Epoch 32 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 438.80batch/s, AVG_LOSS=31.7, LOSS_ITER=35.3]
# Epoch 33 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 119.97batch/s, AVG_LOSS=4.84, LOSS_ITER=6.97]
# Epoch 33 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 376.05batch/s, AVG_LOSS=38.1, LOSS_ITER=24.7]
# Epoch 34 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 127.95batch/s, AVG_LOSS=4.85, LOSS_ITER=5.31]
# Epoch 34 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 449.86batch/s, AVG_LOSS=23.3, LOSS_ITER=4.97]
# Epoch 35 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 129.70batch/s, AVG_LOSS=4.87, LOSS_ITER=5.65]
# Epoch 35 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 424.93batch/s, AVG_LOSS=29.9, LOSS_ITER=32.7]
# Epoch 36 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 112.26batch/s, AVG_LOSS=4.88, LOSS_ITER=3.47]
# Epoch 36 val: 100%|██████████████████████████████████| 27/27 [00:00<00:00, 456.20batch/s, AVG_LOSS=28.3, LOSS_ITER=7.4]
# Epoch 37 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 128.90batch/s, AVG_LOSS=4.68, LOSS_ITER=4.44]
# Epoch 37 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 464.70batch/s, AVG_LOSS=30.5, LOSS_ITER=36.5]
# Epoch 38 train: 100%|██████████████████████████████████| 18/18 [00:00<00:00, 140.75batch/s, AVG_LOSS=4.64, LOSS_ITER=4]
# Epoch 38 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 460.03batch/s, AVG_LOSS=28.6, LOSS_ITER=30.2]
# Epoch 39 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 113.86batch/s, AVG_LOSS=4.45, LOSS_ITER=3.02]
# Epoch 39 val: 100%|███████████████████████████████████| 27/27 [00:00<00:00, 430.36batch/s, AVG_LOSS=23.8, LOSS_ITER=17]
# Epoch 40 train: 100%|████████████████████████████████| 18/18 [00:00<00:00, 136.47batch/s, AVG_LOSS=4.4, LOSS_ITER=2.53]
# Epoch 40 val: 100%|███████████████████████████████████| 27/27 [00:00<00:00, 481.60batch/s, AVG_LOSS=36, LOSS_ITER=44.2]
# Epoch 41 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 124.04batch/s, AVG_LOSS=4.45, LOSS_ITER=5.29]
# Epoch 41 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 460.74batch/s, AVG_LOSS=24.8, LOSS_ITER=20.8]
# Epoch 42 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 113.58batch/s, AVG_LOSS=4.26, LOSS_ITER=5.85]
# Epoch 42 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 456.44batch/s, AVG_LOSS=23.6, LOSS_ITER=10.8]
# Epoch 43 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 126.34batch/s, AVG_LOSS=4.21, LOSS_ITER=4.44]
# Epoch 43 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 487.94batch/s, AVG_LOSS=28.2, LOSS_ITER=30.7]
# Epoch 44 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 126.70batch/s, AVG_LOSS=4.16, LOSS_ITER=5.07]
# Epoch 44 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 518.11batch/s, AVG_LOSS=27.1, LOSS_ITER=13.6]
# Epoch 45 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 153.48batch/s, AVG_LOSS=4.14, LOSS_ITER=3.07]
# Epoch 45 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 587.55batch/s, AVG_LOSS=48.5, LOSS_ITER=33.7]
# Epoch 46 train: 100%|██████████████████████████████████| 18/18 [00:00<00:00, 113.50batch/s, AVG_LOSS=4, LOSS_ITER=5.75]
# Epoch 46 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 422.13batch/s, AVG_LOSS=40.9, LOSS_ITER=29.8]
# Epoch 47 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 122.28batch/s, AVG_LOSS=3.98, LOSS_ITER=4.61]
# Epoch 47 val: 100%|██████████████████████████████████| 27/27 [00:00<00:00, 482.09batch/s, AVG_LOSS=24.5, LOSS_ITER=6.5]
# Epoch 48 train: 100%|███████████████████████████████| 18/18 [00:00<00:00, 105.46batch/s, AVG_LOSS=3.81, LOSS_ITER=3.33]
# Epoch 48 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 442.63batch/s, AVG_LOSS=24.6, LOSS_ITER=21.5]
# Epoch 49 train: 100%|████████████████████████████████| 18/18 [00:00<00:00, 118.98batch/s, AVG_LOSS=3.93, LOSS_ITER=5.9]
# Epoch 49 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 468.16batch/s, AVG_LOSS=38.6, LOSS_ITER=26.4]
# Epoch 50 train: 100%|████████████████████████████████| 18/18 [00:00<00:00, 146.24batch/s, AVG_LOSS=3.79, LOSS_ITER=5.5]
# Epoch 50 val: 100%|█████████████████████████████████| 27/27 [00:00<00:00, 568.25batch/s, AVG_LOSS=36.9, LOSS_ITER=42.6]
#  ========== Training cluster 1 with dataset contain 339 train samples and 43 valid samples ==========
# Epoch 1 train: 100%|██████████████████████████████████| 21/21 [00:00<00:00, 134.66batch/s, AVG_LOSS=126, LOSS_ITER=131]
# Epoch 1 val: 100%|████████████████████████████████████| 43/43 [00:00<00:00, 553.08batch/s, AVG_LOSS=132, LOSS_ITER=132]
#                                                                                                      Best valid loss: 131.9702
# Epoch 2 train: 100%|█████████████████████████████████| 21/21 [00:00<00:00, 150.08batch/s, AVG_LOSS=112, LOSS_ITER=40.8]
# Epoch 2 val: 100%|██████████████████████████████████| 43/43 [00:00<00:00, 396.75batch/s, AVG_LOSS=23.5, LOSS_ITER=22.9]
#                                                                                                      Best valid loss: 23.5006
# Epoch 3 train: 100%|██████████████████████████████████| 21/21 [00:00<00:00, 131.65batch/s, AVG_LOSS=23.4, LOSS_ITER=19]
# Epoch 3 val: 100%|██████████████████████████████████| 43/43 [00:00<00:00, 501.19batch/s, AVG_LOSS=27.6, LOSS_ITER=30.9]
# Epoch 4 train: 100%|████████████████████████████████| 21/21 [00:00<00:00, 162.92batch/s, AVG_LOSS=16.3, LOSS_ITER=16.4]
# Epoch 4 val: 100%|██████████████████████████████████| 43/43 [00:00<00:00, 512.51batch/s, AVG_LOSS=36.1, LOSS_ITER=39.7]
# Epoch 5 train: 100%|████████████████████████████████| 21/21 [00:00<00:00, 158.04batch/s, AVG_LOSS=15.4, LOSS_ITER=12.4]
# Epoch 5 val: 100%|████████████████████████████████████| 43/43 [00:00<00:00, 552.72batch/s, AVG_LOSS=32.6, LOSS_ITER=32]
# Epoch 6 train: 100%|██████████████████████████████████| 21/21 [00:00<00:00, 131.58batch/s, AVG_LOSS=13.9, LOSS_ITER=14]
# Epoch 6 val: 100%|██████████████████████████████████| 43/43 [00:00<00:00, 517.03batch/s, AVG_LOSS=34.7, LOSS_ITER=39.7]
# Epoch 7 train: 100%|████████████████████████████████| 21/21 [00:00<00:00, 137.80batch/s, AVG_LOSS=11.5, LOSS_ITER=9.13]
# Epoch 7 val: 100%|████████████████████████████████████| 43/43 [00:00<00:00, 509.16batch/s, AVG_LOSS=32, LOSS_ITER=35.5]
# Epoch 8 train: 100%|██████████████████████████████████| 21/21 [00:00<00:00, 146.12batch/s, AVG_LOSS=11.1, LOSS_ITER=12]
# Epoch 8 val: 100%|██████████████████████████████████████| 43/43 [00:00<00:00, 483.41batch/s, AVG_LOSS=47, LOSS_ITER=38]
# Epoch 9 train: 100%|██████████████████████████████████| 21/21 [00:00<00:00, 155.93batch/s, AVG_LOSS=9.93, LOSS_ITER=11]
# Epoch 9 val: 100%|██████████████████████████████████| 43/43 [00:00<00:00, 522.47batch/s, AVG_LOSS=20.5, LOSS_ITER=5.99]
#                                                                                                      Best valid loss: 20.5153
# Epoch 10 train: 100%|████████████████████████████████| 21/21 [00:00<00:00, 108.50batch/s, AVG_LOSS=9.2, LOSS_ITER=10.4]
# Epoch 10 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 552.93batch/s, AVG_LOSS=17.8, LOSS_ITER=7.69]
#                                                                                                      Best valid loss: 17.8047
# Epoch 11 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 137.04batch/s, AVG_LOSS=8.83, LOSS_ITER=10.2]
# Epoch 11 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 548.64batch/s, AVG_LOSS=31.1, LOSS_ITER=21.1]
# Epoch 12 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 132.04batch/s, AVG_LOSS=8.42, LOSS_ITER=12.8]
# Epoch 12 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 506.26batch/s, AVG_LOSS=36.9, LOSS_ITER=26.9]
# Epoch 13 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 134.82batch/s, AVG_LOSS=8.49, LOSS_ITER=6.26]
# Epoch 13 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 486.88batch/s, AVG_LOSS=26.7, LOSS_ITER=17.1]
# Epoch 14 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 132.14batch/s, AVG_LOSS=8.22, LOSS_ITER=9.12]
# Epoch 14 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 541.80batch/s, AVG_LOSS=25.2, LOSS_ITER=9.56]
# Epoch 15 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 140.95batch/s, AVG_LOSS=7.84, LOSS_ITER=8.78]
# Epoch 15 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 467.38batch/s, AVG_LOSS=27.6, LOSS_ITER=22.3]
# Epoch 16 train: 100%|████████████████████████████████| 21/21 [00:00<00:00, 144.63batch/s, AVG_LOSS=7.3, LOSS_ITER=6.16]
# Epoch 16 val: 100%|███████████████████████████████████| 43/43 [00:00<00:00, 478.90batch/s, AVG_LOSS=28.5, LOSS_ITER=15]
# Epoch 17 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 123.29batch/s, AVG_LOSS=7.34, LOSS_ITER=6.04]
# Epoch 17 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 393.62batch/s, AVG_LOSS=19.2, LOSS_ITER=15.4]
# Epoch 18 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 133.51batch/s, AVG_LOSS=7.12, LOSS_ITER=10.5]
# Epoch 18 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 508.38batch/s, AVG_LOSS=18.6, LOSS_ITER=13.5]
# Epoch 19 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 143.89batch/s, AVG_LOSS=6.51, LOSS_ITER=5.17]
# Epoch 19 val: 100%|███████████████████████████████████| 43/43 [00:00<00:00, 478.07batch/s, AVG_LOSS=23, LOSS_ITER=18.9]
# Epoch 20 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 136.51batch/s, AVG_LOSS=6.49, LOSS_ITER=4.68]
# Epoch 20 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 542.24batch/s, AVG_LOSS=40.1, LOSS_ITER=33.1]
# Epoch 21 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 155.80batch/s, AVG_LOSS=6.23, LOSS_ITER=4.32]
# Epoch 21 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 570.36batch/s, AVG_LOSS=25.8, LOSS_ITER=23.3]
# Epoch 22 train: 100%|████████████████████████████████| 21/21 [00:00<00:00, 159.46batch/s, AVG_LOSS=6.01, LOSS_ITER=8.4]
# Epoch 22 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 499.01batch/s, AVG_LOSS=24.5, LOSS_ITER=31.4]
# Epoch 23 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 159.01batch/s, AVG_LOSS=6.31, LOSS_ITER=6.93]
# Epoch 23 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 488.41batch/s, AVG_LOSS=22.7, LOSS_ITER=27.3]
# Epoch 24 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 121.24batch/s, AVG_LOSS=5.96, LOSS_ITER=6.95]
# Epoch 24 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 431.86batch/s, AVG_LOSS=19.9, LOSS_ITER=3.88]
# Epoch 25 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 136.68batch/s, AVG_LOSS=5.85, LOSS_ITER=4.24]
# Epoch 25 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 472.04batch/s, AVG_LOSS=31.8, LOSS_ITER=32.4]
# Epoch 26 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 161.87batch/s, AVG_LOSS=5.28, LOSS_ITER=4.42]
# Epoch 26 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 556.18batch/s, AVG_LOSS=19.5, LOSS_ITER=12.3]
# Epoch 27 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 158.33batch/s, AVG_LOSS=5.18, LOSS_ITER=3.92]
# Epoch 27 val: 100%|███████████████████████████████████| 43/43 [00:00<00:00, 548.22batch/s, AVG_LOSS=28.9, LOSS_ITER=32]
# Epoch 28 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 134.38batch/s, AVG_LOSS=5.43, LOSS_ITER=3.07]
# Epoch 28 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 431.85batch/s, AVG_LOSS=24.1, LOSS_ITER=29.1]
# Epoch 29 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 145.69batch/s, AVG_LOSS=5.05, LOSS_ITER=6.45]
# Epoch 29 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 557.18batch/s, AVG_LOSS=28.6, LOSS_ITER=18.9]
# Epoch 30 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 134.29batch/s, AVG_LOSS=4.98, LOSS_ITER=4.66]
# Epoch 30 val: 100%|███████████████████████████████████| 43/43 [00:00<00:00, 497.25batch/s, AVG_LOSS=25, LOSS_ITER=32.3]
# Epoch 31 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 112.53batch/s, AVG_LOSS=4.86, LOSS_ITER=4.99]
# Epoch 31 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 475.59batch/s, AVG_LOSS=25.6, LOSS_ITER=31.2]
# Epoch 32 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 136.80batch/s, AVG_LOSS=4.94, LOSS_ITER=5.39]
# Epoch 32 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 454.78batch/s, AVG_LOSS=38.3, LOSS_ITER=30.6]
# Epoch 33 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 131.45batch/s, AVG_LOSS=4.85, LOSS_ITER=4.93]
# Epoch 33 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 519.24batch/s, AVG_LOSS=26.4, LOSS_ITER=14.8]
# Epoch 34 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 138.83batch/s, AVG_LOSS=4.66, LOSS_ITER=2.73]
# Epoch 34 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 532.13batch/s, AVG_LOSS=37.1, LOSS_ITER=40.3]
# Epoch 35 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 136.31batch/s, AVG_LOSS=4.53, LOSS_ITER=4.19]
# Epoch 35 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 532.58batch/s, AVG_LOSS=21.4, LOSS_ITER=16.9]
# Epoch 36 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 134.10batch/s, AVG_LOSS=4.58, LOSS_ITER=6.18]
# Epoch 36 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 517.91batch/s, AVG_LOSS=24.8, LOSS_ITER=34.3]
# Epoch 37 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 136.45batch/s, AVG_LOSS=4.55, LOSS_ITER=5.89]
# Epoch 37 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 403.28batch/s, AVG_LOSS=36.2, LOSS_ITER=41.1]
# Epoch 38 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 139.39batch/s, AVG_LOSS=4.29, LOSS_ITER=4.26]
# Epoch 38 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 460.02batch/s, AVG_LOSS=22.6, LOSS_ITER=1.68]
# Epoch 39 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 135.59batch/s, AVG_LOSS=4.27, LOSS_ITER=2.67]
# Epoch 39 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 457.09batch/s, AVG_LOSS=19.5, LOSS_ITER=13.4]
# Epoch 40 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 126.77batch/s, AVG_LOSS=4.13, LOSS_ITER=3.47]
# Epoch 40 val: 100%|███████████████████████████████████| 43/43 [00:00<00:00, 448.93batch/s, AVG_LOSS=31.5, LOSS_ITER=44]
# Epoch 41 train: 100%|██████████████████████████████████| 21/21 [00:00<00:00, 137.88batch/s, AVG_LOSS=4.26, LOSS_ITER=5]
# Epoch 41 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 514.76batch/s, AVG_LOSS=26.4, LOSS_ITER=7.24]
# Epoch 42 train: 100%|████████████████████████████████| 21/21 [00:00<00:00, 143.18batch/s, AVG_LOSS=3.97, LOSS_ITER=3.5]
# Epoch 42 val: 100%|███████████████████████████████████| 43/43 [00:00<00:00, 464.99batch/s, AVG_LOSS=23.6, LOSS_ITER=33]
# Epoch 43 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 109.87batch/s, AVG_LOSS=3.97, LOSS_ITER=2.83]
# Epoch 43 val: 100%|███████████████████████████████████| 43/43 [00:00<00:00, 411.17batch/s, AVG_LOSS=35.4, LOSS_ITER=26]
# Epoch 44 train: 100%|████████████████████████████████| 21/21 [00:00<00:00, 126.79batch/s, AVG_LOSS=3.91, LOSS_ITER=2.9]
# Epoch 44 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 439.38batch/s, AVG_LOSS=19.8, LOSS_ITER=10.3]
# Epoch 45 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 154.78batch/s, AVG_LOSS=3.91, LOSS_ITER=2.99]
# Epoch 45 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 556.06batch/s, AVG_LOSS=29.6, LOSS_ITER=12.1]
# Epoch 46 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 123.63batch/s, AVG_LOSS=3.75, LOSS_ITER=3.32]
# Epoch 46 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 452.63batch/s, AVG_LOSS=23.1, LOSS_ITER=30.2]
# Epoch 47 train: 100%|████████████████████████████████| 21/21 [00:00<00:00, 120.01batch/s, AVG_LOSS=3.8, LOSS_ITER=5.62]
# Epoch 47 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 463.68batch/s, AVG_LOSS=32.7, LOSS_ITER=22.8]
# Epoch 48 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 118.28batch/s, AVG_LOSS=3.52, LOSS_ITER=4.59]
# Epoch 48 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 467.43batch/s, AVG_LOSS=31.2, LOSS_ITER=42.4]
# Epoch 49 train: 100%|███████████████████████████████| 21/21 [00:00<00:00, 138.86batch/s, AVG_LOSS=3.64, LOSS_ITER=3.29]
# Epoch 49 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 523.77batch/s, AVG_LOSS=33.6, LOSS_ITER=44.4]
# Epoch 50 train: 100%|████████████████████████████████| 21/21 [00:00<00:00, 100.51batch/s, AVG_LOSS=3.65, LOSS_ITER=3.5]
# Epoch 50 val: 100%|█████████████████████████████████| 43/43 [00:00<00:00, 522.31batch/s, AVG_LOSS=45.4, LOSS_ITER=34.7]

# %% [markdown]
# ### Train Total Model

# %%
# Training total regression model
loss_list, loss_eval, weight = train_regression(
    model=RegressionNet(cluster=False, n_cluster=N_CLUSTER, num_in=NUM_IN),
    metric=MeanLoss(),
    train_dataloader=train_regression_dataloader,
    valid_dataloader=valid_regression_dataloader,
    weight_path=model_path["total"])

# regr.train_multiple_labels(
#     regr_models,
#     X_train, Y_train[:, :2],
#     X_valid, Y_valid[:, :2],
#     model_path["total"])
# Out:
# Epoch 1 train: 100%|██████████████████████████████████| 39/39 [00:20<00:00,  1.92batch/s, AVG_LOSS=101, LOSS_ITER=91.1]
# Epoch 1 val: 100%|████████████████████████████████████| 70/70 [00:00<00:00, 350.40batch/s, AVG_LOSS=60.3, LOSS_ITER=60]
#                                                                                                      Best valid loss: 60.2571
# Epoch 2 train: 100%|█████████████████████████████████| 39/39 [00:20<00:00,  1.92batch/s, AVG_LOSS=42.9, LOSS_ITER=26.6]
# Epoch 2 val: 100%|██████████████████████████████████| 70/70 [00:00<00:00, 524.97batch/s, AVG_LOSS=49.4, LOSS_ITER=6.25]
#                                                                                                      Best valid loss: 49.4253
# Epoch 3 train: 100%|█████████████████████████████████| 39/39 [00:20<00:00,  1.95batch/s, AVG_LOSS=19.3, LOSS_ITER=22.3]
# Epoch 3 val: 100%|██████████████████████████████████| 70/70 [00:00<00:00, 484.97batch/s, AVG_LOSS=50.6, LOSS_ITER=14.8]
# Epoch 4 train: 100%|█████████████████████████████████| 39/39 [00:20<00:00,  1.89batch/s, AVG_LOSS=14.7, LOSS_ITER=17.7]
# Epoch 4 val: 100%|████████████████████████████████████| 70/70 [00:00<00:00, 464.27batch/s, AVG_LOSS=52, LOSS_ITER=13.2]
# Epoch 5 train: 100%|█████████████████████████████████| 39/39 [00:20<00:00,  1.87batch/s, AVG_LOSS=13.4, LOSS_ITER=16.1]
# Epoch 5 val: 100%|██████████████████████████████████| 70/70 [00:00<00:00, 420.53batch/s, AVG_LOSS=51.9, LOSS_ITER=5.72]
# Epoch 6 train: 100%|█████████████████████████████████████| 39/39 [00:21<00:00,  1.85batch/s, AVG_LOSS=12, LOSS_ITER=14]
# Epoch 6 val: 100%|██████████████████████████████████| 70/70 [00:00<00:00, 349.82batch/s, AVG_LOSS=44.9, LOSS_ITER=7.69]
#                                                                                                      Best valid loss: 44.8752
# Epoch 7 train: 100%|█████████████████████████████████| 39/39 [00:20<00:00,  1.94batch/s, AVG_LOSS=11.8, LOSS_ITER=14.6]
# Epoch 7 val: 100%|████████████████████████████████████| 70/70 [00:00<00:00, 559.39batch/s, AVG_LOSS=47, LOSS_ITER=7.43]
# Epoch 8 train: 100%|███████████████████████████████████| 39/39 [00:21<00:00,  1.84batch/s, AVG_LOSS=11.2, LOSS_ITER=14]
# Epoch 8 val: 100%|██████████████████████████████████| 70/70 [00:00<00:00, 473.54batch/s, AVG_LOSS=51.3, LOSS_ITER=17.1]
# Epoch 9 train: 100%|█████████████████████████████████| 39/39 [00:20<00:00,  1.91batch/s, AVG_LOSS=10.8, LOSS_ITER=13.9]
# Epoch 9 val: 100%|██████████████████████████████████| 70/70 [00:00<00:00, 362.17batch/s, AVG_LOSS=52.3, LOSS_ITER=14.1]
# Epoch 10 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.89batch/s, AVG_LOSS=10.7, LOSS_ITER=12.9]
# Epoch 10 val: 100%|███████████████████████████████████| 70/70 [00:00<00:00, 472.79batch/s, AVG_LOSS=54.9, LOSS_ITER=17]
# Epoch 11 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.89batch/s, AVG_LOSS=10.1, LOSS_ITER=13.8]
# Epoch 11 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 500.96batch/s, AVG_LOSS=50.3, LOSS_ITER=11.7]
# Epoch 12 train: 100%|██████████████████████████████████| 39/39 [00:20<00:00,  1.87batch/s, AVG_LOSS=9.75, LOSS_ITER=12]
# Epoch 12 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 411.32batch/s, AVG_LOSS=46.7, LOSS_ITER=4.49]
# Epoch 13 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.92batch/s, AVG_LOSS=8.82, LOSS_ITER=12.1]
# Epoch 13 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 366.37batch/s, AVG_LOSS=52.9, LOSS_ITER=8.64]
# Epoch 14 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.92batch/s, AVG_LOSS=8.67, LOSS_ITER=11.3]
# Epoch 14 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 466.74batch/s, AVG_LOSS=47.6, LOSS_ITER=7.56]
# Epoch 15 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.93batch/s, AVG_LOSS=8.46, LOSS_ITER=9.93]
# Epoch 15 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 308.44batch/s, AVG_LOSS=50.9, LOSS_ITER=4.73]
# Epoch 16 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.89batch/s, AVG_LOSS=8.38, LOSS_ITER=10.8]
# Epoch 16 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 511.95batch/s, AVG_LOSS=50.6, LOSS_ITER=13.4]
# Epoch 17 train: 100%|████████████████████████████████| 39/39 [00:19<00:00,  1.98batch/s, AVG_LOSS=7.79, LOSS_ITER=10.9]
# Epoch 17 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 404.19batch/s, AVG_LOSS=52.9, LOSS_ITER=15.8]
# Epoch 18 train: 100%|████████████████████████████████| 39/39 [00:19<00:00,  1.99batch/s, AVG_LOSS=7.64, LOSS_ITER=12.7]
# Epoch 18 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 556.98batch/s, AVG_LOSS=45.4, LOSS_ITER=8.07]
# Epoch 19 train: 100%|████████████████████████████████| 39/39 [00:19<00:00,  1.96batch/s, AVG_LOSS=7.81, LOSS_ITER=10.8]
# Epoch 19 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 459.62batch/s, AVG_LOSS=45.5, LOSS_ITER=4.61]
# Epoch 20 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.89batch/s, AVG_LOSS=7.14, LOSS_ITER=11.5]
# Epoch 20 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 389.47batch/s, AVG_LOSS=46.5, LOSS_ITER=4.26]
# Epoch 21 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.88batch/s, AVG_LOSS=7.04, LOSS_ITER=10.6]
# Epoch 21 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 323.51batch/s, AVG_LOSS=49.2, LOSS_ITER=5.89]
# Epoch 22 train: 100%|████████████████████████████████| 39/39 [00:19<00:00,  1.97batch/s, AVG_LOSS=6.81, LOSS_ITER=9.47]
# Epoch 22 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 456.05batch/s, AVG_LOSS=49.5, LOSS_ITER=6.81]
# Epoch 23 train: 100%|████████████████████████████████| 39/39 [00:19<00:00,  1.96batch/s, AVG_LOSS=6.74, LOSS_ITER=10.9]
# Epoch 23 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 514.51batch/s, AVG_LOSS=45.8, LOSS_ITER=5.27]
# Epoch 24 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.94batch/s, AVG_LOSS=6.62, LOSS_ITER=9.78]
# Epoch 24 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 444.62batch/s, AVG_LOSS=50.8, LOSS_ITER=4.65]
# Epoch 25 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.94batch/s, AVG_LOSS=6.52, LOSS_ITER=9.05]
# Epoch 25 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 480.34batch/s, AVG_LOSS=50.5, LOSS_ITER=6.04]
# Epoch 26 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.94batch/s, AVG_LOSS=6.02, LOSS_ITER=8.91]
# Epoch 26 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 479.11batch/s, AVG_LOSS=45.9, LOSS_ITER=6.96]
# Epoch 27 train: 100%|█████████████████████████████████| 39/39 [00:20<00:00,  1.94batch/s, AVG_LOSS=6.12, LOSS_ITER=9.5]
# Epoch 27 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 467.15batch/s, AVG_LOSS=45.3, LOSS_ITER=6.65]
# Epoch 28 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.90batch/s, AVG_LOSS=6.08, LOSS_ITER=8.65]
# Epoch 28 val: 100%|███████████████████████████████████| 70/70 [00:00<00:00, 411.83batch/s, AVG_LOSS=48, LOSS_ITER=6.49]
# Epoch 29 train: 100%|████████████████████████████████| 39/39 [00:21<00:00,  1.86batch/s, AVG_LOSS=5.75, LOSS_ITER=9.51]
# Epoch 29 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 468.08batch/s, AVG_LOSS=48.5, LOSS_ITER=5.95]
# Epoch 30 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.90batch/s, AVG_LOSS=5.67, LOSS_ITER=8.37]
# Epoch 30 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 548.29batch/s, AVG_LOSS=50.8, LOSS_ITER=5.76]
# Epoch 31 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.90batch/s, AVG_LOSS=5.55, LOSS_ITER=10.1]
# Epoch 31 val: 100%|██████████████████████████████████| 70/70 [00:00<00:00, 287.06batch/s, AVG_LOSS=44.8, LOSS_ITER=6.5]
#                                                                                                      Best valid loss: 44.7513
# Epoch 32 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.87batch/s, AVG_LOSS=5.39, LOSS_ITER=7.95]
# Epoch 32 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 401.82batch/s, AVG_LOSS=45.6, LOSS_ITER=8.93]
# Epoch 33 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.88batch/s, AVG_LOSS=5.72, LOSS_ITER=8.53]
# Epoch 33 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 442.49batch/s, AVG_LOSS=47.7, LOSS_ITER=8.08]
# Epoch 34 train: 100%|████████████████████████████████| 39/39 [00:19<00:00,  1.96batch/s, AVG_LOSS=5.41, LOSS_ITER=9.98]
# Epoch 34 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 452.93batch/s, AVG_LOSS=49.5, LOSS_ITER=6.71]
# Epoch 35 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.94batch/s, AVG_LOSS=5.09, LOSS_ITER=8.48]
# Epoch 35 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 421.00batch/s, AVG_LOSS=45.3, LOSS_ITER=9.13]
# Epoch 36 train: 100%|█████████████████████████████████| 39/39 [00:19<00:00,  1.97batch/s, AVG_LOSS=5.17, LOSS_ITER=8.7]
# Epoch 36 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 517.12batch/s, AVG_LOSS=49.8, LOSS_ITER=6.63]
# Epoch 37 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.90batch/s, AVG_LOSS=5.08, LOSS_ITER=8.22]
# Epoch 37 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 442.55batch/s, AVG_LOSS=46.2, LOSS_ITER=5.93]
# Epoch 38 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.92batch/s, AVG_LOSS=4.87, LOSS_ITER=8.65]
# Epoch 38 val: 100%|████████████████████████████████████| 70/70 [00:00<00:00, 338.58batch/s, AVG_LOSS=47, LOSS_ITER=6.4]
# Epoch 39 train: 100%|█████████████████████████████████| 39/39 [00:20<00:00,  1.87batch/s, AVG_LOSS=4.7, LOSS_ITER=8.18]
# Epoch 39 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 383.89batch/s, AVG_LOSS=47.9, LOSS_ITER=5.49]
# Epoch 40 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.93batch/s, AVG_LOSS=4.63, LOSS_ITER=8.64]
# Epoch 40 val: 100%|███████████████████████████████████| 70/70 [00:00<00:00, 422.45batch/s, AVG_LOSS=47, LOSS_ITER=5.71]
# Epoch 41 train: 100%|█████████████████████████████████| 39/39 [00:20<00:00,  1.94batch/s, AVG_LOSS=4.67, LOSS_ITER=8.4]
# Epoch 41 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 440.89batch/s, AVG_LOSS=48.4, LOSS_ITER=6.35]
# Epoch 42 train: 100%|████████████████████████████████| 39/39 [00:21<00:00,  1.78batch/s, AVG_LOSS=4.42, LOSS_ITER=8.13]
# Epoch 42 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 299.45batch/s, AVG_LOSS=48.5, LOSS_ITER=5.83]
# Epoch 43 train: 100%|████████████████████████████████| 39/39 [00:21<00:00,  1.82batch/s, AVG_LOSS=4.45, LOSS_ITER=7.42]
# Epoch 43 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 398.28batch/s, AVG_LOSS=52.2, LOSS_ITER=6.77]
# Epoch 44 train: 100%|████████████████████████████████| 39/39 [00:22<00:00,  1.75batch/s, AVG_LOSS=4.62, LOSS_ITER=7.98]
# Epoch 44 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 455.52batch/s, AVG_LOSS=48.9, LOSS_ITER=6.91]
# Epoch 45 train: 100%|████████████████████████████████| 39/39 [00:21<00:00,  1.85batch/s, AVG_LOSS=4.21, LOSS_ITER=8.46]
# Epoch 45 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 405.46batch/s, AVG_LOSS=49.9, LOSS_ITER=6.07]
# Epoch 46 train: 100%|█████████████████████████████████| 39/39 [00:21<00:00,  1.84batch/s, AVG_LOSS=4.1, LOSS_ITER=8.01]
# Epoch 46 val: 100%|███████████████████████████████████| 70/70 [00:00<00:00, 406.26batch/s, AVG_LOSS=50, LOSS_ITER=6.39]
# Epoch 47 train: 100%|████████████████████████████████| 39/39 [00:21<00:00,  1.84batch/s, AVG_LOSS=4.23, LOSS_ITER=7.77]
# Epoch 47 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 358.83batch/s, AVG_LOSS=49.7, LOSS_ITER=6.61]
# Epoch 48 train: 100%|██████████████████████████████████| 39/39 [00:21<00:00,  1.81batch/s, AVG_LOSS=4.1, LOSS_ITER=7.4]
# Epoch 48 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 299.59batch/s, AVG_LOSS=50.2, LOSS_ITER=6.46]
# Epoch 49 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.87batch/s, AVG_LOSS=4.09, LOSS_ITER=7.32]
# Epoch 49 val: 100%|██████████████████████████████████| 70/70 [00:00<00:00, 404.82batch/s, AVG_LOSS=50.4, LOSS_ITER=6.6]
# Epoch 50 train: 100%|████████████████████████████████| 39/39 [00:20<00:00,  1.94batch/s, AVG_LOSS=3.88, LOSS_ITER=7.08]
# Epoch 50 val: 100%|█████████████████████████████████| 70/70 [00:00<00:00, 461.70batch/s, AVG_LOSS=50.3, LOSS_ITER=6.62]

# %% [markdown]
# ### Eval All Regression

# %%
model_evaluation(
    model_total_path=model_path["total"],
    model_dict_path=[
        os.path.join(model_path["ensemble"], "model_0.pth"),
        os.path.join(model_path["ensemble"], "model_1.pth"),
        # os.path.join(model_path["ensemble"], "model_2.pth"),
        # "../../models/uts_models/2023_02_04/ensemble_model/model_2.pth",
    ],
    model_cluster_classifier_path=model_path["cluster_classifier"],
    model_cluster_path=model_path["cluster"],
    metric=MeanLoss(),
    num_in=NUM_IN,
    X_test=X_test,
    Y_test=Y_test[:,:2])

# classic_model_evaluation(
#     model_total_path=model_path["total"],
#     model_dict_path=[
#         os.path.join(model_path["ensemble"], "model_0.sav"),
#         os.path.join(model_path["ensemble"], "model_1.sav"),
#         # os.path.join(model_path["ensemble"], "model_2.sav"),
#         # os.path.join(model_path["ensemble"], "model_3.sav"),
#     ],
#     model_cluster_classifier_path=model_path["cluster_classifier"],
#     model_cluster_path=model_path["cluster"],
#     X_test=X_test,
#     Y_test=Y_test[:, :2])
# Out:
# ===== Load model sklearn successfully =====
# ===== Load model sklearn successfully =====
# Cluster 0 loss:  11.641081813617884
# Cluster 1 loss:  9.321087519824506
# total loss: 10.425595053771694
