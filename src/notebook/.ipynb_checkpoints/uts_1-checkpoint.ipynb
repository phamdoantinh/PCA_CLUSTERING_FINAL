# %%
import os
import random
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pickle

import torch
from torch.utils.data import DataLoader

import sys 

sys.path.insert(1, 'D:/IPS_PCA_CLUSTERING-the_end/')

from copy import deepcopy
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA, KernelPCA
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor

# custom
from src.utils.dataset import RSSIDataset
from src.utils.file_utils import read_data, load_data, load_csv
from src.utils.helper import get_current_date, normalize_data, separates_data_uts, mean_error, clip_gradient, \
    constant_columns, detect_num_feature_rssi, load_data_npz, draw_distribution_cluster, draw_kmean_distortion, \
    draw_kmean_silhouette, set_seed_everything
from src.utils.models import RegressionNet, ClassificationNet, Ensemble_Model, Ensemble_Classic_Model, train_regression, \
    train_classification, model_evaluation, classic_model_evaluation, load_model_classification, save_model_sklearn, \
    load_model_sklearn
from src.utils.loss import MeanLoss
import src.utils.regr_utils as regr

# %% [markdown]
# ### Global config

# %%
N_CLUSTER = 2
NUM_IN = 250
NUM_FEATURES_RSSI = 589
SEED = 2023
N_CPU = os.cpu_count()
set_seed_everything(SEED)

names = [
    "Nearest Neighbors",
    "Linear SVM",
    "RBF SVM",
    # "Gaussian Process",
    "Decision Tree",
    "Random Forest",
    "Neural Net",
    "AdaBoost",
    "Naive Bayes",
    "QDA",
]

date_str = get_current_date()
# date_str = "2023_02_05"
data_type_str = "uts"
n_cluster_str = N_CLUSTER
model_path = {
    'type': 'kernel_pca_250 | UTS | 2_cluster_label',
    'n_clusters': N_CLUSTER,
    'cluster': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_cluster.sav',
    'cluster_classifier': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_cluster_classifier.sav',
    'custom_cluster_classifier': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_custom_cluster_classifier.pth',
    'floor_classifier': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_floor_classifier.sav',
    'ensemble': f"../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/ensemble_model",
    "total": f"../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_total.pth",
}
Path(f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/').mkdir(parents=True, exist_ok=True)
Path(f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/ensemble_model').mkdir(parents=True,
                                                                                                     exist_ok=True)
regr_models = [
    DecisionTreeRegressor(),
    AdaBoostRegressor(),
    GradientBoostingRegressor(),
    XGBRegressor(),
    KNeighborsRegressor(),
    MLPRegressor(),
    SVR(),
]

# %% [markdown]
# ### Data Path

# %%
data_dir = f"../../data/{data_type_str}_data/pca/kernal_pca_cosine_{NUM_IN}/"
# data_dir = f"../../data/{data_type_str}_data/pca/pca_090"

(X_train, Y_train), (X_test, Y_test), (X_valid, Y_valid) = load_data_npz(
    [
        os.path.join(data_dir, "X_train.npz"),
        os.path.join(data_dir, "Y_train.npz"),
        os.path.join(data_dir, "X_test.npz"),
        os.path.join(data_dir, "Y_test.npz"),
        os.path.join(data_dir, "X_valid.npz"),
        os.path.join(data_dir, "Y_valid.npz")
    ]
)

# %%
X_train.shape
# Out:
# (8561, 250)

# %% [markdown]
# ### K-Means Clustering

# %%
cluster = KMeans(n_clusters=N_CLUSTER).fit(Y_train[:, :2])
save_model_sklearn(model_path=model_path["cluster"], model=cluster)

Z_train = cluster.labels_
Z_test = cluster.predict(Y_test[:, :2])
Z_valid = cluster.predict(Y_valid[:, :2])

for i in np.unique(Z_valid):
    print(f"cluster valid {i}", len(Z_valid[Z_valid == i]))

for i in np.unique(Z_train):
    print(f"cluster train {i}", len(Z_train[Z_train == i]))

for i in np.unique(Z_test):
    print(f"cluster test {i}", len(Z_test[Z_test == i]))
# Out:
# ===== Save model sklearn successfully =====
# cluster valid 0 256
# cluster valid 1 291
# cluster train 0 3970
# cluster train 1 4591
# cluster test 0 161
# cluster test 1 227

# %% [markdown]
# ### Đồ thị clustering

# %%
# phân bố dữ liệu theo cluster của label
draw_distribution_cluster(Y_train[:, :2], Z_train, title="Y_TRAIN")
draw_distribution_cluster(Y_test[:, :2], Z_test, title="Y_TEST")
draw_distribution_cluster(Y_valid[:, :2], Z_valid, title="Y_VALID")

# %%
draw_kmean_distortion(Y_train[:, :2], range(1, 10))

# %%
draw_kmean_silhouette(Y_train[:, :2], [2, 3, 4, 5])

# %%
# regression dataset
train_regression_data = RSSIDataset(X_train, Y_train[:, :2])
valid_regression_data = RSSIDataset(X_valid, Y_valid[:, :2])
test_regression_data = RSSIDataset(X_test, Y_test[:, :2])

train_regression_dataloader = DataLoader(train_regression_data, batch_size=16, num_workers=N_CPU, pin_memory=True, drop_last=True)
valid_regression_dataloader = DataLoader(valid_regression_data, batch_size=1, pin_memory=True)
test_regression_dataloader = DataLoader(test_regression_data, batch_size=1, pin_memory=True)

# classifier dataset
train_cluster_dataset = RSSIDataset(X_train, Z_train)
valid_cluster_dataset = RSSIDataset(X_valid, Z_valid)
test_cluster_dataset = RSSIDataset(X_test, Z_test)

train_cluster_loader = DataLoader(train_cluster_dataset, batch_size=16, num_workers=N_CPU, drop_last=True)
valid_cluster_loader = DataLoader(valid_cluster_dataset, batch_size=1)
test_cluster_loader = DataLoader(test_cluster_dataset, batch_size=1)

# %% [markdown]
# ### Train and validate classification models

# %%
clf1 = GaussianNB()
clf2 = MLPClassifier()
clf3 = SVC(kernel='rbf', probability=True)

eclf = VotingClassifier(
    estimators=[
        ('clf1', clf1), ('clf2', clf2), ('clf3', clf3)
    ],
    voting="soft",
    weights=[3, 1, 2]
)

print(f"Train clf1 model: {clf1.__class__.__name__}")
clf1 = clf1.fit(X_train, Z_train)
print(f"Train clf2 model: {clf2.__class__.__name__}")
clf2 = clf2.fit(X_train, Z_train)
print(f"Train clf3 model: {clf3.__class__.__name__}")
clf3 = clf3.fit(X_train, Z_train)
print(f"Train eclf model: {eclf.__class__.__name__}")
eclf = eclf.fit(X_train, Z_train)

print(clf1.score(X_test, Z_test))
print(clf2.score(X_test, Z_test))
print(clf3.score(X_test, Z_test))
print(eclf.score(X_test, Z_test))

save_model_sklearn(model_path["cluster_classifier"], eclf)
# Out:
# Train clf1 model: GaussianNB
# Train clf2 model: MLPClassifier
# Train clf3 model: SVC
# Train eclf model: VotingClassifier
# 0.884020618556701
# 0.8582474226804123
# 0.8788659793814433
# 0.8994845360824743
# ===== Save model sklearn successfully =====

# %%
loaded_model = load_model_sklearn(model_path["cluster_classifier"])
result = loaded_model.score(X_test, Z_test)
print("\nFinal")
print(result)
# Out:
# ===== Load model sklearn successfully =====
#
# Final
# 0.8994845360824743

# %% [markdown]
# ### Train custom cluster classifier

# %%
# net = ClassificationNet(num_in=NUM_IN, num_out=2)
#
# weight_path = model_path["custom_cluster_classifier"]
# train_classification(
#     net,
#     X_train,
#     Z_train,
#     X_valid,
#     Z_valid,
#     weight_path)

# %%
# weight_path = model_path["custom_cluster_classifier"]
# net = load_model_classification(weight_path, num_in=100, num_out=2)
# net.score(X_test, Z_test)

# %% [markdown]
# ### Train Ensemble

# %%
# train model cluster
ens_model = Ensemble_Model(n_cluster=N_CLUSTER, num_in=NUM_IN, ensemble_model_path=model_path["ensemble"])
ens_model.train_student(X_train, Y_train[:,:2], Z_train, X_valid, Y_valid[:,:2], Z_valid)

# classic
# ens_model = Ensemble_Classic_Model(models=regr_models, ensemble_model_path=model_path["ensemble"])
# ens_model.train_student(X_train, Y_train[:, :2], Z_train, X_valid, Y_valid[:, :2], Z_valid)
# Out:
#  ========== Training cluster 0 with dataset contain 3970 train samples and 256 valid samples ==========
# Epoch 1 train: 100%|██████████████████████████████| 248/248 [00:02<00:00, 104.44batch/s, AVG_LOSS=18.4, LOSS_ITER=11.3]
# Epoch 1 val: 100%|████████████████████████████████| 256/256 [00:00<00:00, 328.08batch/s, AVG_LOSS=11.3, LOSS_ITER=8.15]
#                                                                                                      Best valid loss: 11.2503
# Epoch 2 train: 100%|██████████████████████████████| 248/248 [00:02<00:00, 120.06batch/s, AVG_LOSS=5.11, LOSS_ITER=4.63]
# Epoch 2 val: 100%|████████████████████████████████| 256/256 [00:00<00:00, 415.54batch/s, AVG_LOSS=16.2, LOSS_ITER=10.8]
# Epoch 3 train: 100%|██████████████████████████████| 248/248 [00:01<00:00, 124.10batch/s, AVG_LOSS=3.65, LOSS_ITER=3.46]
# Epoch 3 val: 100%|████████████████████████████████| 256/256 [00:00<00:00, 468.30batch/s, AVG_LOSS=13.5, LOSS_ITER=4.32]
# Epoch 4 train: 100%|██████████████████████████████| 248/248 [00:01<00:00, 129.95batch/s, AVG_LOSS=3.11, LOSS_ITER=2.88]
# Epoch 4 val: 100%|████████████████████████████████| 256/256 [00:00<00:00, 354.77batch/s, AVG_LOSS=14.7, LOSS_ITER=11.3]
# Epoch 5 train: 100%|██████████████████████████████| 248/248 [00:02<00:00, 104.56batch/s, AVG_LOSS=2.79, LOSS_ITER=2.89]
# Epoch 5 val: 100%|████████████████████████████████| 256/256 [00:00<00:00, 370.54batch/s, AVG_LOSS=19.7, LOSS_ITER=18.2]
# Epoch 6 train: 100%|███████████████████████████████| 248/248 [00:01<00:00, 126.67batch/s, AVG_LOSS=2.5, LOSS_ITER=2.18]
# Epoch 6 val: 100%|████████████████████████████████| 256/256 [00:00<00:00, 420.51batch/s, AVG_LOSS=27.2, LOSS_ITER=30.7]
# Epoch 7 train: 100%|███████████████████████████████| 248/248 [00:02<00:00, 120.78batch/s, AVG_LOSS=2.3, LOSS_ITER=2.08]
# Epoch 7 val: 100%|████████████████████████████████| 256/256 [00:00<00:00, 455.79batch/s, AVG_LOSS=19.8, LOSS_ITER=19.5]
# Epoch 8 train: 100%|███████████████████████████████| 248/248 [00:01<00:00, 127.35batch/s, AVG_LOSS=2.1, LOSS_ITER=1.69]
# Epoch 8 val: 100%|█████████████████████████████████| 256/256 [00:00<00:00, 420.77batch/s, AVG_LOSS=15.7, LOSS_ITER=6.9]
# Epoch 9 train: 100%|██████████████████████████████| 248/248 [00:01<00:00, 128.84batch/s, AVG_LOSS=1.93, LOSS_ITER=2.58]
# Epoch 9 val: 100%|████████████████████████████████| 256/256 [00:00<00:00, 423.66batch/s, AVG_LOSS=25.4, LOSS_ITER=18.7]
# Epoch 10 train: 100%|█████████████████████████████| 248/248 [00:01<00:00, 129.04batch/s, AVG_LOSS=1.82, LOSS_ITER=1.94]
# Epoch 10 val: 100%|█████████████████████████████████| 256/256 [00:00<00:00, 446.78batch/s, AVG_LOSS=24, LOSS_ITER=20.2]
# Epoch 11 train: 100%|█████████████████████████████| 248/248 [00:01<00:00, 128.98batch/s, AVG_LOSS=1.75, LOSS_ITER=1.28]
# Epoch 11 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 428.40batch/s, AVG_LOSS=17.2, LOSS_ITER=14.6]
# Epoch 12 train: 100%|█████████████████████████████| 248/248 [00:02<00:00, 119.98batch/s, AVG_LOSS=1.65, LOSS_ITER=1.31]
# Epoch 12 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 426.89batch/s, AVG_LOSS=13.4, LOSS_ITER=2.88]
# Epoch 13 train: 100%|█████████████████████████████| 248/248 [00:02<00:00, 115.66batch/s, AVG_LOSS=1.55, LOSS_ITER=1.27]
# Epoch 13 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 349.27batch/s, AVG_LOSS=13.8, LOSS_ITER=7.42]
# Epoch 14 train: 100%|█████████████████████████████| 248/248 [00:02<00:00, 110.43batch/s, AVG_LOSS=1.45, LOSS_ITER=1.93]
# Epoch 14 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 329.35batch/s, AVG_LOSS=28.2, LOSS_ITER=26.8]
# Epoch 15 train: 100%|█████████████████████████████| 248/248 [00:02<00:00, 114.43batch/s, AVG_LOSS=1.37, LOSS_ITER=1.48]
# Epoch 15 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 343.29batch/s, AVG_LOSS=20.2, LOSS_ITER=19.7]
# Epoch 16 train: 100%|█████████████████████████████| 248/248 [00:02<00:00, 118.74batch/s, AVG_LOSS=1.29, LOSS_ITER=1.35]
# Epoch 16 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 290.34batch/s, AVG_LOSS=14.6, LOSS_ITER=10.9]
# Epoch 17 train: 100%|██████████████████████████████| 248/248 [00:02<00:00, 96.16batch/s, AVG_LOSS=1.25, LOSS_ITER=1.99]
# Epoch 17 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 333.64batch/s, AVG_LOSS=16.6, LOSS_ITER=15.4]
# Epoch 18 train: 100%|█████████████████████████████| 248/248 [00:02<00:00, 113.21batch/s, AVG_LOSS=1.18, LOSS_ITER=0.98]
# Epoch 18 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 392.12batch/s, AVG_LOSS=19.7, LOSS_ITER=16.1]
# Epoch 19 train: 100%|████████████████████████████| 248/248 [00:02<00:00, 116.92batch/s, AVG_LOSS=1.15, LOSS_ITER=0.757]
# Epoch 19 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 363.19batch/s, AVG_LOSS=16.3, LOSS_ITER=10.2]
# Epoch 20 train: 100%|█████████████████████████████| 248/248 [00:02<00:00, 110.26batch/s, AVG_LOSS=1.11, LOSS_ITER=1.64]
# Epoch 20 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 366.32batch/s, AVG_LOSS=26.4, LOSS_ITER=25.1]
# Epoch 21 train: 100%|████████████████████████████| 248/248 [00:02<00:00, 119.23batch/s, AVG_LOSS=1.06, LOSS_ITER=0.747]
# Epoch 21 val: 100%|█████████████████████████████████| 256/256 [00:00<00:00, 368.66batch/s, AVG_LOSS=25.4, LOSS_ITER=24]
# Epoch 22 train: 100%|█████████████████████████████| 248/248 [00:02<00:00, 120.61batch/s, AVG_LOSS=1.01, LOSS_ITER=1.97]
# Epoch 22 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 391.66batch/s, AVG_LOSS=19.2, LOSS_ITER=13.6]
# Epoch 23 train: 100%|████████████████████████████| 248/248 [00:02<00:00, 118.18batch/s, AVG_LOSS=0.978, LOSS_ITER=1.04]
# Epoch 23 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 384.52batch/s, AVG_LOSS=19.7, LOSS_ITER=19.3]
# Epoch 24 train: 100%|████████████████████████████| 248/248 [00:02<00:00, 113.05batch/s, AVG_LOSS=0.932, LOSS_ITER=1.86]
# Epoch 24 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 390.93batch/s, AVG_LOSS=16.7, LOSS_ITER=15.9]
# Epoch 25 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 116.59batch/s, AVG_LOSS=0.909, LOSS_ITER=0.664]
# Epoch 25 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 394.04batch/s, AVG_LOSS=13.8, LOSS_ITER=8.49]
# Epoch 26 train: 100%|████████████████████████████| 248/248 [00:02<00:00, 117.20batch/s, AVG_LOSS=0.867, LOSS_ITER=1.53]
# Epoch 26 val: 100%|█████████████████████████████████| 256/256 [00:00<00:00, 400.49batch/s, AVG_LOSS=18, LOSS_ITER=8.26]
# Epoch 27 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 121.47batch/s, AVG_LOSS=0.825, LOSS_ITER=0.746]
# Epoch 27 val: 100%|█████████████████████████████████| 256/256 [00:00<00:00, 376.40batch/s, AVG_LOSS=24, LOSS_ITER=22.1]
# Epoch 28 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 122.05batch/s, AVG_LOSS=0.816, LOSS_ITER=0.563]
# Epoch 28 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 425.71batch/s, AVG_LOSS=21.2, LOSS_ITER=18.8]
# Epoch 29 train: 100%|███████████████████████████| 248/248 [00:01<00:00, 124.14batch/s, AVG_LOSS=0.783, LOSS_ITER=0.437]
# Epoch 29 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 339.84batch/s, AVG_LOSS=18.2, LOSS_ITER=8.62]
# Epoch 30 train: 100%|████████████████████████████| 248/248 [00:02<00:00, 112.70batch/s, AVG_LOSS=0.763, LOSS_ITER=1.36]
# Epoch 30 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 333.20batch/s, AVG_LOSS=27.3, LOSS_ITER=25.7]
# Epoch 31 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 115.28batch/s, AVG_LOSS=0.731, LOSS_ITER=0.686]
# Epoch 31 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 333.18batch/s, AVG_LOSS=21.1, LOSS_ITER=16.6]
# Epoch 32 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 114.87batch/s, AVG_LOSS=0.704, LOSS_ITER=0.322]
# Epoch 32 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 331.79batch/s, AVG_LOSS=22.8, LOSS_ITER=18.3]
# Epoch 33 train: 100%|████████████████████████████| 248/248 [00:02<00:00, 112.67batch/s, AVG_LOSS=0.681, LOSS_ITER=0.59]
# Epoch 33 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 353.00batch/s, AVG_LOSS=19.9, LOSS_ITER=16.2]
# Epoch 34 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 113.57batch/s, AVG_LOSS=0.664, LOSS_ITER=0.926]
# Epoch 34 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 366.00batch/s, AVG_LOSS=15.6, LOSS_ITER=10.9]
# Epoch 35 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 112.75batch/s, AVG_LOSS=0.637, LOSS_ITER=0.515]
# Epoch 35 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 335.71batch/s, AVG_LOSS=25.4, LOSS_ITER=23.4]
# Epoch 36 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 116.26batch/s, AVG_LOSS=0.628, LOSS_ITER=0.424]
# Epoch 36 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 410.52batch/s, AVG_LOSS=13.4, LOSS_ITER=2.71]
# Epoch 37 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 115.64batch/s, AVG_LOSS=0.603, LOSS_ITER=0.283]
# Epoch 37 val: 100%|█████████████████████████████████| 256/256 [00:00<00:00, 406.01batch/s, AVG_LOSS=14, LOSS_ITER=9.23]
# Epoch 38 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 117.87batch/s, AVG_LOSS=0.584, LOSS_ITER=0.913]
# Epoch 38 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 376.43batch/s, AVG_LOSS=15.9, LOSS_ITER=8.97]
# Epoch 39 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 118.28batch/s, AVG_LOSS=0.567, LOSS_ITER=0.382]
# Epoch 39 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 402.51batch/s, AVG_LOSS=15.3, LOSS_ITER=13.1]
# Epoch 40 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 116.81batch/s, AVG_LOSS=0.542, LOSS_ITER=0.276]
# Epoch 40 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 410.83batch/s, AVG_LOSS=18.8, LOSS_ITER=15.7]
# Epoch 41 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 116.86batch/s, AVG_LOSS=0.527, LOSS_ITER=0.463]
# Epoch 41 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 408.68batch/s, AVG_LOSS=22.4, LOSS_ITER=23.5]
# Epoch 42 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 117.56batch/s, AVG_LOSS=0.506, LOSS_ITER=0.792]
# Epoch 42 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 392.79batch/s, AVG_LOSS=23.6, LOSS_ITER=19.2]
# Epoch 43 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 121.13batch/s, AVG_LOSS=0.515, LOSS_ITER=0.303]
# Epoch 43 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 403.92batch/s, AVG_LOSS=14.6, LOSS_ITER=11.7]
# Epoch 44 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 114.81batch/s, AVG_LOSS=0.487, LOSS_ITER=0.255]
# Epoch 44 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 313.08batch/s, AVG_LOSS=14.1, LOSS_ITER=7.78]
# Epoch 45 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 108.37batch/s, AVG_LOSS=0.482, LOSS_ITER=0.521]
# Epoch 45 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 300.41batch/s, AVG_LOSS=14.9, LOSS_ITER=6.97]
# Epoch 46 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 106.14batch/s, AVG_LOSS=0.459, LOSS_ITER=0.435]
# Epoch 46 val: 100%|█████████████████████████████████| 256/256 [00:00<00:00, 333.99batch/s, AVG_LOSS=25, LOSS_ITER=20.8]
# Epoch 47 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 109.49batch/s, AVG_LOSS=0.446, LOSS_ITER=0.234]
# Epoch 47 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 376.36batch/s, AVG_LOSS=14.9, LOSS_ITER=7.62]
# Epoch 48 train: 100%|████████████████████████████| 248/248 [00:02<00:00, 118.98batch/s, AVG_LOSS=0.433, LOSS_ITER=1.04]
# Epoch 48 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 391.87batch/s, AVG_LOSS=16.3, LOSS_ITER=15.9]
# Epoch 49 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 107.88batch/s, AVG_LOSS=0.427, LOSS_ITER=0.242]
# Epoch 49 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 302.50batch/s, AVG_LOSS=14.8, LOSS_ITER=12.2]
# Epoch 50 train: 100%|███████████████████████████| 248/248 [00:02<00:00, 112.66batch/s, AVG_LOSS=0.422, LOSS_ITER=0.196]
# Epoch 50 val: 100%|███████████████████████████████| 256/256 [00:00<00:00, 411.79batch/s, AVG_LOSS=16.4, LOSS_ITER=10.3]
#  ========== Training cluster 1 with dataset contain 4591 train samples and 291 valid samples ==========
# Epoch 1 train: 100%|██████████████████████████████| 286/286 [00:02<00:00, 100.99batch/s, AVG_LOSS=33.9, LOSS_ITER=9.95]
# Epoch 1 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 420.74batch/s, AVG_LOSS=11.8, LOSS_ITER=0.956]
#                                                                                                      Best valid loss: 11.8264
# Epoch 2 train: 100%|██████████████████████████████| 286/286 [00:02<00:00, 118.25batch/s, AVG_LOSS=5.99, LOSS_ITER=5.12]
# Epoch 2 val: 100%|██████████████████████████████████| 291/291 [00:00<00:00, 393.20batch/s, AVG_LOSS=21.2, LOSS_ITER=23]
# Epoch 3 train: 100%|███████████████████████████████| 286/286 [00:02<00:00, 107.01batch/s, AVG_LOSS=4.43, LOSS_ITER=3.1]
# Epoch 3 val: 100%|████████████████████████████████| 291/291 [00:00<00:00, 306.64batch/s, AVG_LOSS=16.4, LOSS_ITER=15.2]
# Epoch 4 train: 100%|██████████████████████████████| 286/286 [00:02<00:00, 110.05batch/s, AVG_LOSS=3.62, LOSS_ITER=3.38]
# Epoch 4 val: 100%|████████████████████████████████| 291/291 [00:00<00:00, 313.09batch/s, AVG_LOSS=20.3, LOSS_ITER=20.2]
# Epoch 5 train: 100%|██████████████████████████████| 286/286 [00:02<00:00, 114.08batch/s, AVG_LOSS=3.15, LOSS_ITER=2.99]
# Epoch 5 val: 100%|██████████████████████████████████| 291/291 [00:00<00:00, 406.33batch/s, AVG_LOSS=13, LOSS_ITER=3.53]
# Epoch 6 train: 100%|██████████████████████████████| 286/286 [00:02<00:00, 117.53batch/s, AVG_LOSS=2.78, LOSS_ITER=2.28]
# Epoch 6 val: 100%|████████████████████████████████| 291/291 [00:00<00:00, 386.63batch/s, AVG_LOSS=21.4, LOSS_ITER=24.3]
# Epoch 7 train: 100%|██████████████████████████████| 286/286 [00:02<00:00, 122.28batch/s, AVG_LOSS=2.51, LOSS_ITER=2.89]
# Epoch 7 val: 100%|█████████████████████████████████| 291/291 [00:00<00:00, 497.94batch/s, AVG_LOSS=13.3, LOSS_ITER=7.4]
# Epoch 8 train: 100%|██████████████████████████████| 286/286 [00:02<00:00, 127.38batch/s, AVG_LOSS=2.33, LOSS_ITER=3.12]
# Epoch 8 val: 100%|████████████████████████████████| 291/291 [00:00<00:00, 490.24batch/s, AVG_LOSS=20.5, LOSS_ITER=20.4]
# Epoch 9 train: 100%|██████████████████████████████| 286/286 [00:02<00:00, 131.34batch/s, AVG_LOSS=2.15, LOSS_ITER=1.63]
# Epoch 9 val: 100%|████████████████████████████████| 291/291 [00:00<00:00, 419.61batch/s, AVG_LOSS=19.1, LOSS_ITER=15.2]
# Epoch 10 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 108.39batch/s, AVG_LOSS=1.97, LOSS_ITER=1.95]
# Epoch 10 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 378.13batch/s, AVG_LOSS=18.1, LOSS_ITER=11.8]
# Epoch 11 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 112.20batch/s, AVG_LOSS=1.87, LOSS_ITER=1.32]
# Epoch 11 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 399.23batch/s, AVG_LOSS=15.5, LOSS_ITER=9.33]
# Epoch 12 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 124.08batch/s, AVG_LOSS=1.78, LOSS_ITER=2.15]
# Epoch 12 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 520.46batch/s, AVG_LOSS=13.3, LOSS_ITER=1.57]
# Epoch 13 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 122.40batch/s, AVG_LOSS=1.69, LOSS_ITER=1.44]
# Epoch 13 val: 100%|█████████████████████████████████| 291/291 [00:00<00:00, 448.10batch/s, AVG_LOSS=17.6, LOSS_ITER=15]
# Epoch 14 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 127.46batch/s, AVG_LOSS=1.61, LOSS_ITER=1.32]
# Epoch 14 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 496.31batch/s, AVG_LOSS=13.6, LOSS_ITER=6.55]
# Epoch 15 train: 100%|██████████████████████████████| 286/286 [00:02<00:00, 130.26batch/s, AVG_LOSS=1.51, LOSS_ITER=1.5]
# Epoch 15 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 542.86batch/s, AVG_LOSS=19.7, LOSS_ITER=18.9]
# Epoch 16 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 128.70batch/s, AVG_LOSS=1.47, LOSS_ITER=1.06]
# Epoch 16 val: 100%|█████████████████████████████████| 291/291 [00:00<00:00, 515.02batch/s, AVG_LOSS=18, LOSS_ITER=17.3]
# Epoch 17 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 131.50batch/s, AVG_LOSS=1.36, LOSS_ITER=1.35]
# Epoch 17 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 486.71batch/s, AVG_LOSS=15.8, LOSS_ITER=10.1]
# Epoch 18 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 130.41batch/s, AVG_LOSS=1.3, LOSS_ITER=0.869]
# Epoch 18 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 485.34batch/s, AVG_LOSS=16.5, LOSS_ITER=15.6]
# Epoch 19 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 133.46batch/s, AVG_LOSS=1.24, LOSS_ITER=1.22]
# Epoch 19 val: 100%|█████████████████████████████████| 291/291 [00:00<00:00, 493.52batch/s, AVG_LOSS=23, LOSS_ITER=22.6]
# Epoch 20 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 121.72batch/s, AVG_LOSS=1.19, LOSS_ITER=1.42]
# Epoch 20 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 454.29batch/s, AVG_LOSS=30.1, LOSS_ITER=30.2]
# Epoch 21 train: 100%|████████████████████████████| 286/286 [00:02<00:00, 127.91batch/s, AVG_LOSS=1.13, LOSS_ITER=0.955]
# Epoch 21 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 421.85batch/s, AVG_LOSS=13.6, LOSS_ITER=4.37]
# Epoch 22 train: 100%|████████████████████████████| 286/286 [00:02<00:00, 123.03batch/s, AVG_LOSS=1.09, LOSS_ITER=0.605]
# Epoch 22 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 468.30batch/s, AVG_LOSS=16.4, LOSS_ITER=16.8]
# Epoch 23 train: 100%|████████████████████████████| 286/286 [00:02<00:00, 126.92batch/s, AVG_LOSS=1.04, LOSS_ITER=0.892]
# Epoch 23 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 460.95batch/s, AVG_LOSS=18.8, LOSS_ITER=14.6]
# Epoch 24 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 122.18batch/s, AVG_LOSS=1.01, LOSS_ITER=1.24]
# Epoch 24 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 380.41batch/s, AVG_LOSS=15.1, LOSS_ITER=7.59]
# Epoch 25 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 121.22batch/s, AVG_LOSS=0.946, LOSS_ITER=0.898]
# Epoch 25 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 497.99batch/s, AVG_LOSS=17.3, LOSS_ITER=17.8]
# Epoch 26 train: 100%|████████████████████████████| 286/286 [00:02<00:00, 116.61batch/s, AVG_LOSS=0.92, LOSS_ITER=0.564]
# Epoch 26 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 387.03batch/s, AVG_LOSS=19.6, LOSS_ITER=18.7]
# Epoch 27 train: 100%|████████████████████████████| 286/286 [00:02<00:00, 116.42batch/s, AVG_LOSS=0.887, LOSS_ITER=1.01]
# Epoch 27 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 442.13batch/s, AVG_LOSS=15.6, LOSS_ITER=6.36]
# Epoch 28 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 127.54batch/s, AVG_LOSS=0.857, LOSS_ITER=0.651]
# Epoch 28 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 419.88batch/s, AVG_LOSS=25.3, LOSS_ITER=26.1]
# Epoch 29 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 119.81batch/s, AVG_LOSS=0.843, LOSS_ITER=0.865]
# Epoch 29 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 465.94batch/s, AVG_LOSS=20.5, LOSS_ITER=18.4]
# Epoch 30 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 121.34batch/s, AVG_LOSS=0.816, LOSS_ITER=0.823]
# Epoch 30 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 417.93batch/s, AVG_LOSS=13.1, LOSS_ITER=5.13]
# Epoch 31 train: 100%|████████████████████████████| 286/286 [00:02<00:00, 123.06batch/s, AVG_LOSS=0.794, LOSS_ITER=1.35]
# Epoch 31 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 427.27batch/s, AVG_LOSS=23.4, LOSS_ITER=23.9]
# Epoch 32 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 128.82batch/s, AVG_LOSS=0.753, LOSS_ITER=0.568]
# Epoch 32 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 495.74batch/s, AVG_LOSS=23.6, LOSS_ITER=21.9]
# Epoch 33 train: 100%|████████████████████████████| 286/286 [00:02<00:00, 129.00batch/s, AVG_LOSS=0.733, LOSS_ITER=1.05]
# Epoch 33 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 526.37batch/s, AVG_LOSS=17.8, LOSS_ITER=15.9]
# Epoch 34 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 129.28batch/s, AVG_LOSS=0.71, LOSS_ITER=1.57]
# Epoch 34 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 447.75batch/s, AVG_LOSS=20.4, LOSS_ITER=20.8]
# Epoch 35 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 123.37batch/s, AVG_LOSS=0.684, LOSS_ITER=0.446]
# Epoch 35 val: 100%|█████████████████████████████████| 291/291 [00:00<00:00, 453.97batch/s, AVG_LOSS=22, LOSS_ITER=21.4]
# Epoch 36 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 117.92batch/s, AVG_LOSS=0.669, LOSS_ITER=0.737]
# Epoch 36 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 409.20batch/s, AVG_LOSS=22.1, LOSS_ITER=24.2]
# Epoch 37 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 116.83batch/s, AVG_LOSS=0.665, LOSS_ITER=0.634]
# Epoch 37 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 427.31batch/s, AVG_LOSS=18.4, LOSS_ITER=12.9]
# Epoch 38 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 121.26batch/s, AVG_LOSS=0.642, LOSS_ITER=0.684]
# Epoch 38 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 391.86batch/s, AVG_LOSS=21.3, LOSS_ITER=22.1]
# Epoch 39 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 114.57batch/s, AVG_LOSS=0.611, LOSS_ITER=0.568]
# Epoch 39 val: 100%|█████████████████████████████████| 291/291 [00:00<00:00, 389.12batch/s, AVG_LOSS=14, LOSS_ITER=8.54]
# Epoch 40 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 109.52batch/s, AVG_LOSS=0.601, LOSS_ITER=0.517]
# Epoch 40 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 348.89batch/s, AVG_LOSS=16.7, LOSS_ITER=8.74]
# Epoch 41 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 118.09batch/s, AVG_LOSS=0.584, LOSS_ITER=0.577]
# Epoch 41 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 459.20batch/s, AVG_LOSS=23.6, LOSS_ITER=25.8]
# Epoch 42 train: 100%|█████████████████████████████| 286/286 [00:02<00:00, 131.67batch/s, AVG_LOSS=0.564, LOSS_ITER=0.6]
# Epoch 42 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 455.78batch/s, AVG_LOSS=20.9, LOSS_ITER=20.6]
# Epoch 43 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 136.65batch/s, AVG_LOSS=0.545, LOSS_ITER=0.224]
# Epoch 43 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 409.51batch/s, AVG_LOSS=14.2, LOSS_ITER=7.99]
# Epoch 44 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 130.25batch/s, AVG_LOSS=0.539, LOSS_ITER=0.655]
# Epoch 44 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 449.53batch/s, AVG_LOSS=13.5, LOSS_ITER=5.58]
# Epoch 45 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 132.55batch/s, AVG_LOSS=0.528, LOSS_ITER=0.465]
# Epoch 45 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 403.63batch/s, AVG_LOSS=16.1, LOSS_ITER=16.3]
# Epoch 46 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 118.94batch/s, AVG_LOSS=0.505, LOSS_ITER=0.618]
# Epoch 46 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 422.48batch/s, AVG_LOSS=23.3, LOSS_ITER=20.5]
# Epoch 47 train: 100%|████████████████████████████| 286/286 [00:02<00:00, 116.80batch/s, AVG_LOSS=0.499, LOSS_ITER=0.65]
# Epoch 47 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 402.18batch/s, AVG_LOSS=19.1, LOSS_ITER=19.3]
# Epoch 48 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 117.15batch/s, AVG_LOSS=0.489, LOSS_ITER=0.303]
# Epoch 48 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 408.91batch/s, AVG_LOSS=17.3, LOSS_ITER=17.8]
# Epoch 49 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 119.63batch/s, AVG_LOSS=0.478, LOSS_ITER=0.756]
# Epoch 49 val: 100%|█████████████████████████████████| 291/291 [00:00<00:00, 403.28batch/s, AVG_LOSS=14, LOSS_ITER=11.7]
# Epoch 50 train: 100%|███████████████████████████| 286/286 [00:02<00:00, 115.31batch/s, AVG_LOSS=0.466, LOSS_ITER=0.311]
# Epoch 50 val: 100%|███████████████████████████████| 291/291 [00:00<00:00, 403.38batch/s, AVG_LOSS=18.2, LOSS_ITER=17.4]

# %% [markdown]
# ### Train Total Model

# %%
# Training total regression model
loss_list, loss_eval, weight = train_regression(
    model=RegressionNet(cluster=False, n_cluster=N_CLUSTER, num_in=NUM_IN),
    metric=MeanLoss(),
    train_dataloader=train_regression_dataloader,
    valid_dataloader=valid_regression_dataloader,
    weight_path=model_path["total"])

# regr.train_multiple_labels(
#     regr_models,
#     X_train, Y_train[:, :2],
#     X_valid, Y_valid[:, :2],
#     model_path["total"])
# Out:
# Epoch 1 train: 100%|███████████████████████████████| 535/535 [00:30<00:00, 17.27batch/s, AVG_LOSS=20.1, LOSS_ITER=12.7]
# Epoch 1 val: 100%|██████████████████████████████████| 547/547 [00:01<00:00, 401.61batch/s, AVG_LOSS=47.5, LOSS_ITER=79]
#                                                                                                      Best valid loss: 47.4818
# Epoch 2 train: 100%|███████████████████████████████| 535/535 [00:29<00:00, 17.98batch/s, AVG_LOSS=5.62, LOSS_ITER=4.06]
# Epoch 2 val: 100%|██████████████████████████████████| 547/547 [00:01<00:00, 383.09batch/s, AVG_LOSS=48.3, LOSS_ITER=72]
# Epoch 3 train: 100%|███████████████████████████████| 535/535 [00:30<00:00, 17.56batch/s, AVG_LOSS=4.26, LOSS_ITER=3.71]
# Epoch 3 val: 100%|████████████████████████████████| 547/547 [00:01<00:00, 397.20batch/s, AVG_LOSS=48.5, LOSS_ITER=69.6]
# Epoch 4 train: 100%|████████████████████████████████| 535/535 [00:25<00:00, 21.23batch/s, AVG_LOSS=3.6, LOSS_ITER=2.53]
# Epoch 4 val: 100%|████████████████████████████████| 547/547 [00:01<00:00, 430.85batch/s, AVG_LOSS=48.9, LOSS_ITER=69.9]
# Epoch 5 train: 100%|███████████████████████████████| 535/535 [00:26<00:00, 20.21batch/s, AVG_LOSS=3.18, LOSS_ITER=2.42]
# Epoch 5 val: 100%|████████████████████████████████| 547/547 [00:01<00:00, 438.76batch/s, AVG_LOSS=48.5, LOSS_ITER=69.2]
# Epoch 6 train: 100%|███████████████████████████████| 535/535 [00:25<00:00, 20.83batch/s, AVG_LOSS=2.89, LOSS_ITER=2.36]
# Epoch 6 val: 100%|██████████████████████████████████| 547/547 [00:01<00:00, 445.64batch/s, AVG_LOSS=49, LOSS_ITER=70.5]
# Epoch 7 train: 100%|███████████████████████████████| 535/535 [00:25<00:00, 20.60batch/s, AVG_LOSS=2.64, LOSS_ITER=2.02]
# Epoch 7 val: 100%|██████████████████████████████████| 547/547 [00:01<00:00, 348.52batch/s, AVG_LOSS=48.6, LOSS_ITER=72]
# Epoch 8 train: 100%|███████████████████████████████| 535/535 [00:25<00:00, 21.02batch/s, AVG_LOSS=2.46, LOSS_ITER=1.67]
# Epoch 8 val: 100%|████████████████████████████████| 547/547 [00:01<00:00, 456.76batch/s, AVG_LOSS=48.5, LOSS_ITER=72.9]
# Epoch 9 train: 100%|███████████████████████████████| 535/535 [00:24<00:00, 22.10batch/s, AVG_LOSS=2.27, LOSS_ITER=1.67]
# Epoch 9 val: 100%|████████████████████████████████| 547/547 [00:01<00:00, 484.57batch/s, AVG_LOSS=48.6, LOSS_ITER=72.2]
# Epoch 10 train: 100%|██████████████████████████████| 535/535 [00:23<00:00, 22.31batch/s, AVG_LOSS=2.14, LOSS_ITER=1.43]
# Epoch 10 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 481.84batch/s, AVG_LOSS=47.9, LOSS_ITER=71.1]
# Epoch 11 train: 100%|█████████████████████████████████| 535/535 [00:24<00:00, 22.15batch/s, AVG_LOSS=2, LOSS_ITER=1.42]
# Epoch 11 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 413.66batch/s, AVG_LOSS=48.4, LOSS_ITER=71.1]
# Epoch 12 train: 100%|███████████████████████████████| 535/535 [00:27<00:00, 19.48batch/s, AVG_LOSS=1.88, LOSS_ITER=1.4]
# Epoch 12 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 392.20batch/s, AVG_LOSS=48.4, LOSS_ITER=72.1]
# Epoch 13 train: 100%|██████████████████████████████| 535/535 [00:24<00:00, 21.90batch/s, AVG_LOSS=1.79, LOSS_ITER=1.29]
# Epoch 13 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 426.92batch/s, AVG_LOSS=48.5, LOSS_ITER=71.3]
# Epoch 14 train: 100%|██████████████████████████████| 535/535 [00:24<00:00, 21.69batch/s, AVG_LOSS=1.72, LOSS_ITER=1.08]
# Epoch 14 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 404.56batch/s, AVG_LOSS=48.4, LOSS_ITER=71.8]
# Epoch 15 train: 100%|██████████████████████████████| 535/535 [00:24<00:00, 21.64batch/s, AVG_LOSS=1.62, LOSS_ITER=1.12]
# Epoch 15 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 400.44batch/s, AVG_LOSS=48.7, LOSS_ITER=72.4]
# Epoch 16 train: 100%|█████████████████████████████| 535/535 [00:24<00:00, 21.72batch/s, AVG_LOSS=1.53, LOSS_ITER=0.898]
# Epoch 16 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 399.19batch/s, AVG_LOSS=48.9, LOSS_ITER=70.8]
# Epoch 17 train: 100%|█████████████████████████████| 535/535 [00:25<00:00, 21.14batch/s, AVG_LOSS=1.48, LOSS_ITER=0.899]
# Epoch 17 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 490.67batch/s, AVG_LOSS=48.8, LOSS_ITER=71.7]
# Epoch 18 train: 100%|██████████████████████████████| 535/535 [00:25<00:00, 21.39batch/s, AVG_LOSS=1.41, LOSS_ITER=1.01]
# Epoch 18 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 446.50batch/s, AVG_LOSS=48.9, LOSS_ITER=71.7]
# Epoch 19 train: 100%|█████████████████████████████| 535/535 [00:24<00:00, 21.78batch/s, AVG_LOSS=1.36, LOSS_ITER=0.858]
# Epoch 19 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 493.00batch/s, AVG_LOSS=48.7, LOSS_ITER=71.8]
# Epoch 20 train: 100%|█████████████████████████████| 535/535 [00:26<00:00, 20.52batch/s, AVG_LOSS=1.31, LOSS_ITER=0.731]
# Epoch 20 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 407.98batch/s, AVG_LOSS=48.8, LOSS_ITER=71.9]
# Epoch 21 train: 100%|█████████████████████████████| 535/535 [00:25<00:00, 21.16batch/s, AVG_LOSS=1.24, LOSS_ITER=0.646]
# Epoch 21 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 354.73batch/s, AVG_LOSS=48.9, LOSS_ITER=72.5]
# Epoch 22 train: 100%|██████████████████████████████| 535/535 [00:24<00:00, 21.56batch/s, AVG_LOSS=1.2, LOSS_ITER=0.587]
# Epoch 22 val: 100%|█████████████████████████████████| 547/547 [00:01<00:00, 443.31batch/s, AVG_LOSS=49, LOSS_ITER=71.9]
# Epoch 23 train: 100%|█████████████████████████████| 535/535 [00:24<00:00, 21.71batch/s, AVG_LOSS=1.17, LOSS_ITER=0.892]
# Epoch 23 val: 100%|█████████████████████████████████| 547/547 [00:01<00:00, 491.08batch/s, AVG_LOSS=49, LOSS_ITER=70.9]
# Epoch 24 train: 100%|█████████████████████████████| 535/535 [00:24<00:00, 21.63batch/s, AVG_LOSS=1.12, LOSS_ITER=0.688]
# Epoch 24 val: 100%|█████████████████████████████████| 547/547 [00:01<00:00, 391.38batch/s, AVG_LOSS=48.7, LOSS_ITER=72]
# Epoch 25 train: 100%|█████████████████████████████| 535/535 [00:24<00:00, 21.64batch/s, AVG_LOSS=1.09, LOSS_ITER=0.604]
# Epoch 25 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 493.05batch/s, AVG_LOSS=48.8, LOSS_ITER=71.5]
# Epoch 26 train: 100%|█████████████████████████████| 535/535 [00:25<00:00, 20.90batch/s, AVG_LOSS=1.05, LOSS_ITER=0.722]
# Epoch 26 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 357.98batch/s, AVG_LOSS=48.9, LOSS_ITER=72.3]
# Epoch 27 train: 100%|█████████████████████████████| 535/535 [00:24<00:00, 21.99batch/s, AVG_LOSS=1.03, LOSS_ITER=0.682]
# Epoch 27 val: 100%|█████████████████████████████████| 547/547 [00:01<00:00, 498.74batch/s, AVG_LOSS=48.7, LOSS_ITER=72]
# Epoch 28 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 22.01batch/s, AVG_LOSS=0.985, LOSS_ITER=0.639]
# Epoch 28 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 466.16batch/s, AVG_LOSS=48.7, LOSS_ITER=71.2]
# Epoch 29 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 21.49batch/s, AVG_LOSS=0.969, LOSS_ITER=0.574]
# Epoch 29 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 452.58batch/s, AVG_LOSS=48.8, LOSS_ITER=71.7]
# Epoch 30 train: 100%|████████████████████████████| 535/535 [00:25<00:00, 21.23batch/s, AVG_LOSS=0.938, LOSS_ITER=0.665]
# Epoch 30 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 401.40batch/s, AVG_LOSS=48.7, LOSS_ITER=71.7]
# Epoch 31 train: 100%|████████████████████████████| 535/535 [00:25<00:00, 21.12batch/s, AVG_LOSS=0.907, LOSS_ITER=0.573]
# Epoch 31 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 453.15batch/s, AVG_LOSS=48.6, LOSS_ITER=71.5]
# Epoch 32 train: 100%|█████████████████████████████| 535/535 [00:24<00:00, 21.46batch/s, AVG_LOSS=0.87, LOSS_ITER=0.501]
# Epoch 32 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 446.88batch/s, AVG_LOSS=48.8, LOSS_ITER=71.9]
# Epoch 33 train: 100%|████████████████████████████| 535/535 [00:25<00:00, 21.05batch/s, AVG_LOSS=0.851, LOSS_ITER=0.504]
# Epoch 33 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 474.93batch/s, AVG_LOSS=48.8, LOSS_ITER=72.1]
# Epoch 34 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 21.42batch/s, AVG_LOSS=0.835, LOSS_ITER=0.493]
# Epoch 34 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 382.28batch/s, AVG_LOSS=48.7, LOSS_ITER=71.4]
# Epoch 35 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 21.42batch/s, AVG_LOSS=0.801, LOSS_ITER=0.562]
# Epoch 35 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 380.25batch/s, AVG_LOSS=48.7, LOSS_ITER=71.5]
# Epoch 36 train: 100%|████████████████████████████| 535/535 [00:25<00:00, 21.32batch/s, AVG_LOSS=0.791, LOSS_ITER=0.408]
# Epoch 36 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 442.87batch/s, AVG_LOSS=48.8, LOSS_ITER=72.3]
# Epoch 37 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 21.84batch/s, AVG_LOSS=0.764, LOSS_ITER=0.397]
# Epoch 37 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 471.95batch/s, AVG_LOSS=48.7, LOSS_ITER=72.1]
# Epoch 38 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 22.28batch/s, AVG_LOSS=0.748, LOSS_ITER=0.355]
# Epoch 38 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 462.54batch/s, AVG_LOSS=48.8, LOSS_ITER=71.8]
# Epoch 39 train: 100%|████████████████████████████| 535/535 [00:23<00:00, 22.49batch/s, AVG_LOSS=0.726, LOSS_ITER=0.497]
# Epoch 39 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 484.21batch/s, AVG_LOSS=48.7, LOSS_ITER=71.7]
# Epoch 40 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 21.77batch/s, AVG_LOSS=0.703, LOSS_ITER=0.438]
# Epoch 40 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 436.18batch/s, AVG_LOSS=48.7, LOSS_ITER=71.8]
# Epoch 41 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 22.17batch/s, AVG_LOSS=0.688, LOSS_ITER=0.396]
# Epoch 41 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 437.59batch/s, AVG_LOSS=48.8, LOSS_ITER=71.6]
# Epoch 42 train: 100%|████████████████████████████| 535/535 [00:25<00:00, 21.07batch/s, AVG_LOSS=0.672, LOSS_ITER=0.356]
# Epoch 42 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 423.52batch/s, AVG_LOSS=48.7, LOSS_ITER=71.7]
# Epoch 43 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 21.63batch/s, AVG_LOSS=0.658, LOSS_ITER=0.378]
# Epoch 43 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 478.98batch/s, AVG_LOSS=48.8, LOSS_ITER=71.5]
# Epoch 44 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 21.41batch/s, AVG_LOSS=0.644, LOSS_ITER=0.405]
# Epoch 44 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 471.36batch/s, AVG_LOSS=48.7, LOSS_ITER=71.8]
# Epoch 45 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 21.92batch/s, AVG_LOSS=0.627, LOSS_ITER=0.409]
# Epoch 45 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 469.70batch/s, AVG_LOSS=48.7, LOSS_ITER=71.6]
# Epoch 46 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 21.90batch/s, AVG_LOSS=0.615, LOSS_ITER=0.365]
# Epoch 46 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 445.43batch/s, AVG_LOSS=48.8, LOSS_ITER=71.9]
# Epoch 47 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 21.56batch/s, AVG_LOSS=0.599, LOSS_ITER=0.347]
# Epoch 47 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 477.61batch/s, AVG_LOSS=48.8, LOSS_ITER=72.3]
# Epoch 48 train: 100%|████████████████████████████| 535/535 [00:25<00:00, 21.38batch/s, AVG_LOSS=0.589, LOSS_ITER=0.342]
# Epoch 48 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 367.60batch/s, AVG_LOSS=48.8, LOSS_ITER=71.8]
# Epoch 49 train: 100%|████████████████████████████| 535/535 [00:24<00:00, 22.09batch/s, AVG_LOSS=0.572, LOSS_ITER=0.284]
# Epoch 49 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 381.41batch/s, AVG_LOSS=48.8, LOSS_ITER=71.8]
# Epoch 50 train: 100%|████████████████████████████| 535/535 [00:25<00:00, 21.32batch/s, AVG_LOSS=0.563, LOSS_ITER=0.317]
# Epoch 50 val: 100%|███████████████████████████████| 547/547 [00:01<00:00, 350.50batch/s, AVG_LOSS=48.7, LOSS_ITER=71.7]

# %% [markdown]
# ### Eval All Regression

# %%
model_evaluation(
    model_total_path=model_path["total"],
    model_dict_path=[
        os.path.join(model_path["ensemble"], "model_0.pth"),
        os.path.join(model_path["ensemble"], "model_1.pth"),
        # os.path.join(model_path["ensemble"], "model_2.pth"),
        # "../../models/uts_models/2023_02_04/ensemble_model/model_2.pth",
    ],
    model_cluster_classifier_path=model_path["cluster_classifier"],
    model_cluster_path=model_path["cluster"],
    metric=MeanLoss(),
    num_in=NUM_IN,
    X_test=X_test,
    Y_test=Y_test[:,:2])

# classic_model_evaluation(
#     model_total_path=model_path["total"],
#     model_dict_path=[
#         os.path.join(model_path["ensemble"], "model_0.sav"),
#         os.path.join(model_path["ensemble"], "model_1.sav"),
#         # os.path.join(model_path["ensemble"], "model_2.sav"),
#         # os.path.join(model_path["ensemble"], "model_3.sav"),
#     ],
#     model_cluster_classifier_path=model_path["cluster_classifier"],
#     model_cluster_path=model_path["cluster"],
#     X_test=X_test,
#     Y_test=Y_test[:, :2])
# Out:
# ===== Load model sklearn successfully =====
# ===== Load model sklearn successfully =====
# Cluster 0 loss:  9.038383841691982
# Cluster 1 loss:  8.099115719951012
# total loss: 8.50580913348834
