# %%
import os
import random
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pickle

import torch
from torch.utils.data import DataLoader

import sys 
#Note: Change path to your folder dir (This is mine)
path_to_dir = "C:/Users/Asus/Documents/IPS_PCA_CLUSTERING"

sys.path.insert(1, path_to_dir)

from copy import deepcopy
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA, KernelPCA
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor

# custom
from src.utils.dataset import RSSIDataset
from src.utils.file_utils import read_data, load_data, load_csv
from src.utils.helper import get_current_date, normalize_data, separates_data_uts, mean_error, clip_gradient, \
    constant_columns, detect_num_feature_rssi, load_data_npz, draw_distribution_cluster, draw_kmean_distortion, \
    draw_kmean_silhouette, set_seed_everything
from src.utils.models import RegressionNet, ClassificationNet, Ensemble_Model, Ensemble_Classic_Model, train_regression, \
    train_classification, model_evaluation, classic_model_evaluation, load_model_classification, save_model_sklearn, \
    load_model_sklearn
from src.utils.loss import MeanLoss
import src.utils.regr_utils as regr

# %% [markdown]
# ### Global config

# %%
N_CLUSTER = 2
NUM_IN = 250
NUM_FEATURES_RSSI = 589
SEED = 2023
N_CPU = os.cpu_count()
set_seed_everything(SEED)

names = [
    "Nearest Neighbors",
    "Linear SVM",
    "RBF SVM",
    # "Gaussian Process",
    "Decision Tree",
    "Random Forest",
    "Neural Net",
    "AdaBoost",
    "Naive Bayes",
    "QDA",
]

date_str = get_current_date()
# date_str = "2023_02_05"
data_type_str = "uts"
n_cluster_str = N_CLUSTER
model_path = {
    'type': 'kernel_pca_250 | UTS | 2_cluster_label',
    'n_clusters': N_CLUSTER,
    'cluster': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_cluster.sav',
    'cluster_classifier': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_cluster_classifier.sav',
    'custom_cluster_classifier': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_custom_cluster_classifier.pth',
    'floor_classifier': f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_floor_classifier.sav',
    'ensemble': f"../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/ensemble_model",
    "total": f"../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/model_total.pth",
}
Path(f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/').mkdir(parents=True, exist_ok=True)
Path(f'../../models/{data_type_str}_models/cluster_{n_cluster_str}/{date_str}/ensemble_model').mkdir(parents=True,
                                                                                                     exist_ok=True)
regr_models = [
    DecisionTreeRegressor(),
    AdaBoostRegressor(),
    GradientBoostingRegressor(),
    XGBRegressor(),
    KNeighborsRegressor(),
    MLPRegressor(),
    SVR(),
]

# %% [markdown]
# ### Data Path

# %%
data_dir = f"../../data/{data_type_str}_data/pca/kernal_pca_cosine_{NUM_IN}/"
# data_dir = f"../../data/{data_type_str}_data/pca/pca_090"

(X_train, Y_train), (X_test, Y_test), (X_valid, Y_valid) = load_data_npz(
    [
        os.path.join(data_dir, "X_train.npz"),
        os.path.join(data_dir, "Y_train.npz"),
        os.path.join(data_dir, "X_test.npz"),
        os.path.join(data_dir, "Y_test.npz"),
        os.path.join(data_dir, "X_valid.npz"),
        os.path.join(data_dir, "Y_valid.npz")
    ]
)

# %%
X_train.shape
# Out:
# (8288, 250)

# %% [markdown]
# ### K-Means Clustering

# %%
cluster = KMeans(n_clusters=N_CLUSTER).fit(Y_train[:, :2])
save_model_sklearn(model_path=model_path["cluster"], model=cluster)

Z_train = cluster.labels_
Z_test = cluster.predict(Y_test[:, :2])
Z_valid = cluster.predict(Y_valid[:, :2])

for i in np.unique(Z_valid):
    print(f"cluster valid {i}", len(Z_valid[Z_valid == i]))

for i in np.unique(Z_train):
    print(f"cluster train {i}", len(Z_train[Z_train == i]))

for i in np.unique(Z_test):
    print(f"cluster test {i}", len(Z_test[Z_test == i]))
# Out:
# ===== Save model sklearn successfully =====
# cluster valid 0 447
# cluster valid 1 373
# cluster train 0 4435
# cluster train 1 3853
# cluster test 0 227
# cluster test 1 161

# %% [markdown]
# ### Đồ thị clustering

# %%
# phân bố dữ liệu theo cluster của label
draw_distribution_cluster(Y_train[:, :2], Z_train, title="Y_TRAIN")
draw_distribution_cluster(Y_test[:, :2], Z_test, title="Y_TEST")
draw_distribution_cluster(Y_valid[:, :2], Z_valid, title="Y_VALID")

# %%
draw_kmean_distortion(Y_train[:, :2], range(1, 10))

# %%
draw_kmean_silhouette(Y_train[:, :2], [2, 3, 4, 5])

# %%
# regression dataset
train_regression_data = RSSIDataset(X_train, Y_train[:, :2])
valid_regression_data = RSSIDataset(X_valid, Y_valid[:, :2])
test_regression_data = RSSIDataset(X_test, Y_test[:, :2])

train_regression_dataloader = DataLoader(train_regression_data, batch_size=16, num_workers=N_CPU, pin_memory=True, drop_last=True)
valid_regression_dataloader = DataLoader(valid_regression_data, batch_size=1, pin_memory=True)
test_regression_dataloader = DataLoader(test_regression_data, batch_size=1, pin_memory=True)

# classifier dataset
train_cluster_dataset = RSSIDataset(X_train, Z_train)
valid_cluster_dataset = RSSIDataset(X_valid, Z_valid)
test_cluster_dataset = RSSIDataset(X_test, Z_test)

train_cluster_loader = DataLoader(train_cluster_dataset, batch_size=16, num_workers=N_CPU, drop_last=True)
valid_cluster_loader = DataLoader(valid_cluster_dataset, batch_size=1)
test_cluster_loader = DataLoader(test_cluster_dataset, batch_size=1)

# %% [markdown]
# ### Train and validate classification models

# %%
clf1 = GaussianNB()
clf2 = MLPClassifier()
clf3 = SVC(kernel='rbf', probability=True)

eclf = VotingClassifier(
    estimators=[
        ('clf1', clf1), ('clf2', clf2), ('clf3', clf3)
    ],
    voting="soft",
    weights=[3, 1, 2]
)

print(f"Train clf1 model: {clf1.__class__.__name__}")
clf1 = clf1.fit(X_train, Z_train)
print(f"Train clf2 model: {clf2.__class__.__name__}")
clf2 = clf2.fit(X_train, Z_train)
print(f"Train clf3 model: {clf3.__class__.__name__}")
clf3 = clf3.fit(X_train, Z_train)
print(f"Train eclf model: {eclf.__class__.__name__}")
eclf = eclf.fit(X_train, Z_train)

print(clf1.score(X_test, Z_test))
print(clf2.score(X_test, Z_test))
print(clf3.score(X_test, Z_test))
print(eclf.score(X_test, Z_test))

save_model_sklearn(model_path["cluster_classifier"], eclf)
# Out:
# Train clf1 model: GaussianNB
# Train clf2 model: MLPClassifier
# Train clf3 model: SVC
# Train eclf model: VotingClassifier
# 0.8814432989690721
# 0.8608247422680413
# 0.8788659793814433
# 0.8969072164948454
# ===== Save model sklearn successfully =====

# %%
loaded_model = load_model_sklearn(model_path["cluster_classifier"])
result = loaded_model.score(X_test, Z_test)
print("\nFinal")
print(result)
# Out:
# ===== Load model sklearn successfully =====
#
# Final
# 0.8969072164948454

# %% [markdown]
# ### Train custom cluster classifier

# %%
# net = ClassificationNet(num_in=NUM_IN, num_out=2)
#
# weight_path = model_path["custom_cluster_classifier"]
# train_classification(
#     net,
#     X_train,
#     Z_train,
#     X_valid,
#     Z_valid,
#     weight_path)

# %%
# weight_path = model_path["custom_cluster_classifier"]
# net = load_model_classification(weight_path, num_in=100, num_out=2)
# net.score(X_test, Z_test)

# %% [markdown]
# ### Train Ensemble

# %%
# train model cluster
ens_model = Ensemble_Model(n_cluster=N_CLUSTER, num_in=NUM_IN, ensemble_model_path=model_path["ensemble"])
ens_model.train_student(X_train, Y_train[:,:2], Z_train, X_valid, Y_valid[:,:2], Z_valid)

# classic
# ens_model = Ensemble_Classic_Model(models=regr_models, ensemble_model_path=model_path["ensemble"])
# ens_model.train_student(X_train, Y_train[:, :2], Z_train, X_valid, Y_valid[:, :2], Z_valid)
# Out:
#  ========== Training cluster 0 with dataset contain 4435 train samples and 447 valid samples ==========
# Epoch 1 train: 100%|████████████████████████████████| 277/277 [00:02<00:00, 130.26batch/s, AVG_LOSS=37, LOSS_ITER=14.3]
# Epoch 1 val: 100%|████████████████████████████████| 447/447 [00:00<00:00, 506.31batch/s, AVG_LOSS=10.6, LOSS_ITER=20.2]
#                                                                                                      Best valid loss: 10.6394
# Epoch 2 train: 100%|██████████████████████████████| 277/277 [00:01<00:00, 152.05batch/s, AVG_LOSS=6.28, LOSS_ITER=4.53]
# Epoch 2 val: 100%|████████████████████████████████| 447/447 [00:00<00:00, 535.99batch/s, AVG_LOSS=12.3, LOSS_ITER=17.9]
# Epoch 3 train: 100%|██████████████████████████████| 277/277 [00:01<00:00, 150.40batch/s, AVG_LOSS=4.47, LOSS_ITER=2.35]
# Epoch 3 val: 100%|████████████████████████████████| 447/447 [00:00<00:00, 509.01batch/s, AVG_LOSS=15.8, LOSS_ITER=8.22]
# Epoch 4 train: 100%|██████████████████████████████| 277/277 [00:01<00:00, 158.35batch/s, AVG_LOSS=3.73, LOSS_ITER=3.59]
# Epoch 4 val: 100%|████████████████████████████████| 447/447 [00:00<00:00, 515.68batch/s, AVG_LOSS=13.7, LOSS_ITER=6.09]
# Epoch 5 train: 100%|███████████████████████████████| 277/277 [00:01<00:00, 161.37batch/s, AVG_LOSS=3.2, LOSS_ITER=2.15]
# Epoch 5 val: 100%|██████████████████████████████████| 447/447 [00:00<00:00, 521.78batch/s, AVG_LOSS=14, LOSS_ITER=17.5]
# Epoch 6 train: 100%|██████████████████████████████| 277/277 [00:01<00:00, 158.94batch/s, AVG_LOSS=2.87, LOSS_ITER=2.97]
# Epoch 6 val: 100%|████████████████████████████████| 447/447 [00:00<00:00, 529.41batch/s, AVG_LOSS=13.3, LOSS_ITER=18.7]
# Epoch 7 train: 100%|██████████████████████████████| 277/277 [00:01<00:00, 157.83batch/s, AVG_LOSS=2.58, LOSS_ITER=2.64]
# Epoch 7 val: 100%|████████████████████████████████| 447/447 [00:00<00:00, 520.57batch/s, AVG_LOSS=17.1, LOSS_ITER=28.3]
# Epoch 8 train: 100%|██████████████████████████████| 277/277 [00:01<00:00, 162.33batch/s, AVG_LOSS=2.39, LOSS_ITER=2.28]
# Epoch 8 val: 100%|████████████████████████████████| 447/447 [00:00<00:00, 514.36batch/s, AVG_LOSS=25.6, LOSS_ITER=8.87]
# Epoch 9 train: 100%|██████████████████████████████| 277/277 [00:01<00:00, 159.73batch/s, AVG_LOSS=2.16, LOSS_ITER=1.83]
# Epoch 9 val: 100%|████████████████████████████████| 447/447 [00:00<00:00, 502.71batch/s, AVG_LOSS=13.5, LOSS_ITER=22.9]
# Epoch 10 train: 100%|█████████████████████████████| 277/277 [00:01<00:00, 159.22batch/s, AVG_LOSS=2.04, LOSS_ITER=1.62]
# Epoch 10 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 525.86batch/s, AVG_LOSS=14.2, LOSS_ITER=9.79]
# Epoch 11 train: 100%|█████████████████████████████| 277/277 [00:01<00:00, 156.34batch/s, AVG_LOSS=1.92, LOSS_ITER=1.74]
# Epoch 11 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 510.99batch/s, AVG_LOSS=21.2, LOSS_ITER=32.8]
# Epoch 12 train: 100%|█████████████████████████████| 277/277 [00:01<00:00, 157.71batch/s, AVG_LOSS=1.83, LOSS_ITER=1.29]
# Epoch 12 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 506.14batch/s, AVG_LOSS=13.6, LOSS_ITER=16.1]
# Epoch 13 train: 100%|█████████████████████████████| 277/277 [00:01<00:00, 158.51batch/s, AVG_LOSS=1.65, LOSS_ITER=1.59]
# Epoch 13 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 530.50batch/s, AVG_LOSS=14.5, LOSS_ITER=15.4]
# Epoch 14 train: 100%|██████████████████████████████| 277/277 [00:01<00:00, 156.35batch/s, AVG_LOSS=1.54, LOSS_ITER=1.4]
# Epoch 14 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 498.38batch/s, AVG_LOSS=14.4, LOSS_ITER=10.6]
# Epoch 15 train: 100%|█████████████████████████████| 277/277 [00:01<00:00, 159.26batch/s, AVG_LOSS=1.54, LOSS_ITER=2.15]
# Epoch 15 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 522.82batch/s, AVG_LOSS=13.9, LOSS_ITER=15.5]
# Epoch 16 train: 100%|██████████████████████████████| 277/277 [00:01<00:00, 157.70batch/s, AVG_LOSS=1.4, LOSS_ITER=1.61]
# Epoch 16 val: 100%|█████████████████████████████████| 447/447 [00:00<00:00, 500.30batch/s, AVG_LOSS=13.9, LOSS_ITER=17]
# Epoch 17 train: 100%|█████████████████████████████| 277/277 [00:01<00:00, 154.39batch/s, AVG_LOSS=1.34, LOSS_ITER=1.11]
# Epoch 17 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 513.89batch/s, AVG_LOSS=18.2, LOSS_ITER=21.1]
# Epoch 18 train: 100%|█████████████████████████████| 277/277 [00:01<00:00, 149.91batch/s, AVG_LOSS=1.26, LOSS_ITER=1.67]
# Epoch 18 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 503.30batch/s, AVG_LOSS=13.2, LOSS_ITER=11.2]
# Epoch 19 train: 100%|█████████████████████████████| 277/277 [00:01<00:00, 162.02batch/s, AVG_LOSS=1.22, LOSS_ITER=1.06]
# Epoch 19 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 515.02batch/s, AVG_LOSS=14.1, LOSS_ITER=12.4]
# Epoch 20 train: 100%|█████████████████████████████| 277/277 [00:01<00:00, 156.19batch/s, AVG_LOSS=1.17, LOSS_ITER=1.04]
# Epoch 20 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 522.67batch/s, AVG_LOSS=20.2, LOSS_ITER=29.1]
# Epoch 21 train: 100%|████████████████████████████| 277/277 [00:01<00:00, 151.26batch/s, AVG_LOSS=1.13, LOSS_ITER=0.673]
# Epoch 21 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 524.51batch/s, AVG_LOSS=15.6, LOSS_ITER=15.9]
# Epoch 22 train: 100%|█████████████████████████████| 277/277 [00:01<00:00, 160.49batch/s, AVG_LOSS=1.08, LOSS_ITER=1.03]
# Epoch 22 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 504.73batch/s, AVG_LOSS=20.4, LOSS_ITER=24.9]
# Epoch 23 train: 100%|█████████████████████████████| 277/277 [00:01<00:00, 156.85batch/s, AVG_LOSS=1.05, LOSS_ITER=1.03]
# Epoch 23 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 532.97batch/s, AVG_LOSS=21.7, LOSS_ITER=27.5]
# Epoch 24 train: 100%|████████████████████████████| 277/277 [00:01<00:00, 159.23batch/s, AVG_LOSS=0.996, LOSS_ITER=1.15]
# Epoch 24 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 511.61batch/s, AVG_LOSS=16.3, LOSS_ITER=11.7]
# Epoch 25 train: 100%|████████████████████████████| 277/277 [00:01<00:00, 157.66batch/s, AVG_LOSS=0.954, LOSS_ITER=1.03]
# Epoch 25 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 492.35batch/s, AVG_LOSS=20.5, LOSS_ITER=27.5]
# Epoch 26 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 154.33batch/s, AVG_LOSS=0.933, LOSS_ITER=0.909]
# Epoch 26 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 514.06batch/s, AVG_LOSS=16.5, LOSS_ITER=7.32]
# Epoch 27 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 152.55batch/s, AVG_LOSS=0.882, LOSS_ITER=0.684]
# Epoch 27 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 521.79batch/s, AVG_LOSS=17.2, LOSS_ITER=5.69]
# Epoch 28 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 152.57batch/s, AVG_LOSS=0.852, LOSS_ITER=0.591]
# Epoch 28 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 479.54batch/s, AVG_LOSS=13.7, LOSS_ITER=7.99]
# Epoch 29 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 155.76batch/s, AVG_LOSS=0.835, LOSS_ITER=0.779]
# Epoch 29 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 533.71batch/s, AVG_LOSS=23.8, LOSS_ITER=30.5]
# Epoch 30 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 155.03batch/s, AVG_LOSS=0.816, LOSS_ITER=0.482]
# Epoch 30 val: 100%|█████████████████████████████████| 447/447 [00:00<00:00, 527.33batch/s, AVG_LOSS=13.6, LOSS_ITER=13]
# Epoch 31 train: 100%|████████████████████████████| 277/277 [00:01<00:00, 155.86batch/s, AVG_LOSS=0.787, LOSS_ITER=1.27]
# Epoch 31 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 516.75batch/s, AVG_LOSS=19.2, LOSS_ITER=13.7]
# Epoch 32 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 158.07batch/s, AVG_LOSS=0.748, LOSS_ITER=0.564]
# Epoch 32 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 516.47batch/s, AVG_LOSS=17.9, LOSS_ITER=15.7]
# Epoch 33 train: 100%|████████████████████████████| 277/277 [00:01<00:00, 153.50batch/s, AVG_LOSS=0.75, LOSS_ITER=0.569]
# Epoch 33 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 515.26batch/s, AVG_LOSS=14.6, LOSS_ITER=17.3]
# Epoch 34 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 156.11batch/s, AVG_LOSS=0.704, LOSS_ITER=0.686]
# Epoch 34 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 497.89batch/s, AVG_LOSS=13.7, LOSS_ITER=8.13]
# Epoch 35 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 154.56batch/s, AVG_LOSS=0.689, LOSS_ITER=0.825]
# Epoch 35 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 514.06batch/s, AVG_LOSS=15.1, LOSS_ITER=15.6]
# Epoch 36 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 157.84batch/s, AVG_LOSS=0.664, LOSS_ITER=0.374]
# Epoch 36 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 504.65batch/s, AVG_LOSS=13.9, LOSS_ITER=15.1]
# Epoch 37 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 157.61batch/s, AVG_LOSS=0.652, LOSS_ITER=0.471]
# Epoch 37 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 520.73batch/s, AVG_LOSS=21.9, LOSS_ITER=15.7]
# Epoch 38 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 154.07batch/s, AVG_LOSS=0.621, LOSS_ITER=0.344]
# Epoch 38 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 480.56batch/s, AVG_LOSS=24.2, LOSS_ITER=27.8]
# Epoch 39 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 153.58batch/s, AVG_LOSS=0.623, LOSS_ITER=0.713]
# Epoch 39 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 515.27batch/s, AVG_LOSS=13.6, LOSS_ITER=10.1]
# Epoch 40 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 158.39batch/s, AVG_LOSS=0.598, LOSS_ITER=0.442]
# Epoch 40 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 518.21batch/s, AVG_LOSS=15.6, LOSS_ITER=11.6]
# Epoch 41 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 164.80batch/s, AVG_LOSS=0.578, LOSS_ITER=0.233]
# Epoch 41 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 509.21batch/s, AVG_LOSS=16.9, LOSS_ITER=5.52]
# Epoch 42 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 158.61batch/s, AVG_LOSS=0.572, LOSS_ITER=0.344]
# Epoch 42 val: 100%|█████████████████████████████████| 447/447 [00:00<00:00, 532.74batch/s, AVG_LOSS=16.3, LOSS_ITER=11]
# Epoch 43 train: 100%|████████████████████████████| 277/277 [00:01<00:00, 155.37batch/s, AVG_LOSS=0.562, LOSS_ITER=0.29]
# Epoch 43 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 488.36batch/s, AVG_LOSS=16.8, LOSS_ITER=12.3]
# Epoch 44 train: 100%|████████████████████████████| 277/277 [00:01<00:00, 157.05batch/s, AVG_LOSS=0.539, LOSS_ITER=0.53]
# Epoch 44 val: 100%|████████████████████████████████| 447/447 [00:00<00:00, 510.45batch/s, AVG_LOSS=13.6, LOSS_ITER=6.5]
# Epoch 45 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 161.84batch/s, AVG_LOSS=0.523, LOSS_ITER=0.524]
# Epoch 45 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 526.72batch/s, AVG_LOSS=17.6, LOSS_ITER=22.6]
# Epoch 46 train: 100%|████████████████████████████| 277/277 [00:01<00:00, 153.74batch/s, AVG_LOSS=0.51, LOSS_ITER=0.437]
# Epoch 46 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 529.78batch/s, AVG_LOSS=21.7, LOSS_ITER=10.1]
# Epoch 47 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 158.32batch/s, AVG_LOSS=0.489, LOSS_ITER=0.277]
# Epoch 47 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 515.07batch/s, AVG_LOSS=13.8, LOSS_ITER=14.1]
# Epoch 48 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 162.63batch/s, AVG_LOSS=0.486, LOSS_ITER=0.254]
# Epoch 48 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 518.49batch/s, AVG_LOSS=15.9, LOSS_ITER=10.7]
# Epoch 49 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 159.48batch/s, AVG_LOSS=0.468, LOSS_ITER=0.231]
# Epoch 49 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 523.73batch/s, AVG_LOSS=14.9, LOSS_ITER=16.8]
# Epoch 50 train: 100%|███████████████████████████| 277/277 [00:01<00:00, 159.11batch/s, AVG_LOSS=0.463, LOSS_ITER=0.237]
# Epoch 50 val: 100%|███████████████████████████████| 447/447 [00:00<00:00, 498.55batch/s, AVG_LOSS=14.7, LOSS_ITER=6.22]
#  ========== Training cluster 1 with dataset contain 3853 train samples and 373 valid samples ==========
# Epoch 1 train: 100%|██████████████████████████████| 240/240 [00:01<00:00, 127.55batch/s, AVG_LOSS=17.5, LOSS_ITER=8.37]
# Epoch 1 val: 100%|████████████████████████████████| 373/373 [00:00<00:00, 508.51batch/s, AVG_LOSS=23.8, LOSS_ITER=11.7]
#                                                                                                      Best valid loss: 23.8039
# Epoch 2 train: 100%|██████████████████████████████| 240/240 [00:01<00:00, 166.62batch/s, AVG_LOSS=4.91, LOSS_ITER=3.32]
# Epoch 2 val: 100%|████████████████████████████████| 373/373 [00:00<00:00, 505.89batch/s, AVG_LOSS=18.6, LOSS_ITER=11.5]
#                                                                                                      Best valid loss: 18.6437
# Epoch 3 train: 100%|███████████████████████████████| 240/240 [00:01<00:00, 155.86batch/s, AVG_LOSS=3.57, LOSS_ITER=2.8]
# Epoch 3 val: 100%|████████████████████████████████| 373/373 [00:00<00:00, 516.59batch/s, AVG_LOSS=21.9, LOSS_ITER=42.8]
# Epoch 4 train: 100%|██████████████████████████████| 240/240 [00:01<00:00, 164.71batch/s, AVG_LOSS=3.06, LOSS_ITER=3.37]
# Epoch 4 val: 100%|████████████████████████████████| 373/373 [00:00<00:00, 522.93batch/s, AVG_LOSS=13.9, LOSS_ITER=26.4]
#                                                                                                      Best valid loss: 13.8889
# Epoch 5 train: 100%|██████████████████████████████| 240/240 [00:01<00:00, 159.94batch/s, AVG_LOSS=2.72, LOSS_ITER=1.67]
# Epoch 5 val: 100%|████████████████████████████████| 373/373 [00:00<00:00, 483.43batch/s, AVG_LOSS=18.8, LOSS_ITER=13.6]
# Epoch 6 train: 100%|██████████████████████████████| 240/240 [00:01<00:00, 157.90batch/s, AVG_LOSS=2.43, LOSS_ITER=3.41]
# Epoch 6 val: 100%|████████████████████████████████| 373/373 [00:00<00:00, 507.69batch/s, AVG_LOSS=16.4, LOSS_ITER=18.9]
# Epoch 7 train: 100%|██████████████████████████████| 240/240 [00:01<00:00, 159.84batch/s, AVG_LOSS=2.27, LOSS_ITER=2.04]
# Epoch 7 val: 100%|████████████████████████████████| 373/373 [00:00<00:00, 520.94batch/s, AVG_LOSS=22.3, LOSS_ITER=44.4]
# Epoch 8 train: 100%|██████████████████████████████| 240/240 [00:01<00:00, 166.31batch/s, AVG_LOSS=2.05, LOSS_ITER=1.27]
# Epoch 8 val: 100%|██████████████████████████████████| 373/373 [00:00<00:00, 506.53batch/s, AVG_LOSS=22, LOSS_ITER=44.5]
# Epoch 9 train: 100%|██████████████████████████████| 240/240 [00:01<00:00, 162.34batch/s, AVG_LOSS=1.91, LOSS_ITER=2.11]
# Epoch 9 val: 100%|████████████████████████████████| 373/373 [00:00<00:00, 533.14batch/s, AVG_LOSS=21.4, LOSS_ITER=12.2]
# Epoch 10 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 163.53batch/s, AVG_LOSS=1.82, LOSS_ITER=2.05]
# Epoch 10 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 521.14batch/s, AVG_LOSS=14.8, LOSS_ITER=19.9]
# Epoch 11 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 168.23batch/s, AVG_LOSS=1.73, LOSS_ITER=1.82]
# Epoch 11 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 505.13batch/s, AVG_LOSS=22.8, LOSS_ITER=12.1]
# Epoch 12 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 160.05batch/s, AVG_LOSS=1.65, LOSS_ITER=1.34]
# Epoch 12 val: 100%|█████████████████████████████████| 373/373 [00:00<00:00, 543.89batch/s, AVG_LOSS=13.6, LOSS_ITER=25]
#                                                                                                      Best valid loss: 13.5530
# Epoch 13 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 156.31batch/s, AVG_LOSS=1.55, LOSS_ITER=1.37]
# Epoch 13 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 524.21batch/s, AVG_LOSS=22.7, LOSS_ITER=43.1]
# Epoch 14 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 154.40batch/s, AVG_LOSS=1.46, LOSS_ITER=1.91]
# Epoch 14 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 546.20batch/s, AVG_LOSS=24.1, LOSS_ITER=8.42]
# Epoch 15 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 155.38batch/s, AVG_LOSS=1.42, LOSS_ITER=1.38]
# Epoch 15 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 531.66batch/s, AVG_LOSS=18.7, LOSS_ITER=10.4]
# Epoch 16 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 157.10batch/s, AVG_LOSS=1.31, LOSS_ITER=1.56]
# Epoch 16 val: 100%|█████████████████████████████████| 373/373 [00:00<00:00, 532.93batch/s, AVG_LOSS=18, LOSS_ITER=13.6]
# Epoch 17 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 162.28batch/s, AVG_LOSS=1.28, LOSS_ITER=1.44]
# Epoch 17 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 538.63batch/s, AVG_LOSS=14.6, LOSS_ITER=33.1]
# Epoch 18 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 154.25batch/s, AVG_LOSS=1.21, LOSS_ITER=1.38]
# Epoch 18 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 511.55batch/s, AVG_LOSS=15.4, LOSS_ITER=28.4]
# Epoch 19 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 159.25batch/s, AVG_LOSS=1.19, LOSS_ITER=1.23]
# Epoch 19 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 512.04batch/s, AVG_LOSS=14.1, LOSS_ITER=30.4]
# Epoch 20 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 160.21batch/s, AVG_LOSS=1.12, LOSS_ITER=1.38]
# Epoch 20 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 508.29batch/s, AVG_LOSS=20.4, LOSS_ITER=42.8]
# Epoch 21 train: 100%|██████████████████████████████| 240/240 [00:01<00:00, 159.71batch/s, AVG_LOSS=1.1, LOSS_ITER=1.24]
# Epoch 21 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 503.22batch/s, AVG_LOSS=16.3, LOSS_ITER=20.8]
# Epoch 22 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 160.97batch/s, AVG_LOSS=1.06, LOSS_ITER=1.15]
# Epoch 22 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 508.97batch/s, AVG_LOSS=17.2, LOSS_ITER=16.8]
# Epoch 23 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 161.11batch/s, AVG_LOSS=0.974, LOSS_ITER=0.893]
# Epoch 23 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 508.53batch/s, AVG_LOSS=17.8, LOSS_ITER=34.4]
# Epoch 24 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 161.67batch/s, AVG_LOSS=0.959, LOSS_ITER=0.804]
# Epoch 24 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 517.36batch/s, AVG_LOSS=24.3, LOSS_ITER=4.14]
# Epoch 25 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 163.99batch/s, AVG_LOSS=0.905, LOSS_ITER=0.911]
# Epoch 25 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 507.14batch/s, AVG_LOSS=20.8, LOSS_ITER=14.1]
# Epoch 26 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 164.78batch/s, AVG_LOSS=0.896, LOSS_ITER=0.529]
# Epoch 26 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 503.76batch/s, AVG_LOSS=14.7, LOSS_ITER=22.5]
# Epoch 27 train: 100%|████████████████████████████| 240/240 [00:01<00:00, 160.18batch/s, AVG_LOSS=0.863, LOSS_ITER=2.47]
# Epoch 27 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 516.44batch/s, AVG_LOSS=18.2, LOSS_ITER=12.6]
# Epoch 28 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 150.80batch/s, AVG_LOSS=0.823, LOSS_ITER=0.502]
# Epoch 28 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 505.00batch/s, AVG_LOSS=20.4, LOSS_ITER=10.9]
# Epoch 29 train: 100%|████████████████████████████| 240/240 [00:01<00:00, 159.69batch/s, AVG_LOSS=0.829, LOSS_ITER=2.08]
# Epoch 29 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 459.57batch/s, AVG_LOSS=21.1, LOSS_ITER=37.5]
# Epoch 30 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 131.28batch/s, AVG_LOSS=0.779, LOSS_ITER=0.618]
# Epoch 30 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 492.46batch/s, AVG_LOSS=16.6, LOSS_ITER=18.4]
# Epoch 31 train: 100%|████████████████████████████| 240/240 [00:01<00:00, 143.74batch/s, AVG_LOSS=0.742, LOSS_ITER=1.13]
# Epoch 31 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 482.45batch/s, AVG_LOSS=15.4, LOSS_ITER=29.4]
# Epoch 32 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 147.35batch/s, AVG_LOSS=0.734, LOSS_ITER=0.833]
# Epoch 32 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 488.87batch/s, AVG_LOSS=20.4, LOSS_ITER=24.2]
# Epoch 33 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 150.94batch/s, AVG_LOSS=0.705, LOSS_ITER=0.354]
# Epoch 33 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 484.60batch/s, AVG_LOSS=15.3, LOSS_ITER=34.7]
# Epoch 34 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 152.52batch/s, AVG_LOSS=0.686, LOSS_ITER=0.464]
# Epoch 34 val: 100%|█████████████████████████████████| 373/373 [00:00<00:00, 496.77batch/s, AVG_LOSS=15, LOSS_ITER=23.1]
# Epoch 35 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 149.34batch/s, AVG_LOSS=0.669, LOSS_ITER=0.775]
# Epoch 35 val: 100%|█████████████████████████████████| 373/373 [00:00<00:00, 499.37batch/s, AVG_LOSS=21, LOSS_ITER=7.47]
# Epoch 36 train: 100%|████████████████████████████| 240/240 [00:01<00:00, 146.58batch/s, AVG_LOSS=0.65, LOSS_ITER=0.383]
# Epoch 36 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 482.58batch/s, AVG_LOSS=13.8, LOSS_ITER=24.8]
# Epoch 37 train: 100%|████████████████████████████| 240/240 [00:01<00:00, 144.83batch/s, AVG_LOSS=0.642, LOSS_ITER=1.04]
# Epoch 37 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 498.01batch/s, AVG_LOSS=16.3, LOSS_ITER=20.1]
# Epoch 38 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 149.43batch/s, AVG_LOSS=0.617, LOSS_ITER=0.686]
# Epoch 38 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 484.66batch/s, AVG_LOSS=15.4, LOSS_ITER=33.8]
# Epoch 39 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 135.37batch/s, AVG_LOSS=0.609, LOSS_ITER=0.387]
# Epoch 39 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 484.59batch/s, AVG_LOSS=17.6, LOSS_ITER=39.1]
# Epoch 40 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 144.96batch/s, AVG_LOSS=0.58, LOSS_ITER=1.19]
# Epoch 40 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 482.02batch/s, AVG_LOSS=18.7, LOSS_ITER=40.5]
# Epoch 41 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 147.54batch/s, AVG_LOSS=0.567, LOSS_ITER=0.519]
# Epoch 41 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 500.54batch/s, AVG_LOSS=19.4, LOSS_ITER=36.9]
# Epoch 42 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 148.62batch/s, AVG_LOSS=0.561, LOSS_ITER=0.583]
# Epoch 42 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 511.67batch/s, AVG_LOSS=27.9, LOSS_ITER=52.6]
# Epoch 43 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 145.34batch/s, AVG_LOSS=0.537, LOSS_ITER=0.375]
# Epoch 43 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 473.89batch/s, AVG_LOSS=15.7, LOSS_ITER=19.8]
# Epoch 44 train: 100%|████████████████████████████| 240/240 [00:01<00:00, 147.64batch/s, AVG_LOSS=0.528, LOSS_ITER=1.15]
# Epoch 44 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 496.23batch/s, AVG_LOSS=14.2, LOSS_ITER=24.6]
# Epoch 45 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 142.86batch/s, AVG_LOSS=0.518, LOSS_ITER=0.342]
# Epoch 45 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 484.02batch/s, AVG_LOSS=18.8, LOSS_ITER=12.4]
# Epoch 46 train: 100%|████████████████████████████| 240/240 [00:01<00:00, 150.25batch/s, AVG_LOSS=0.501, LOSS_ITER=0.31]
# Epoch 46 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 415.24batch/s, AVG_LOSS=16.8, LOSS_ITER=18.4]
# Epoch 47 train: 100%|█████████████████████████████| 240/240 [00:01<00:00, 138.94batch/s, AVG_LOSS=0.5, LOSS_ITER=0.435]
# Epoch 47 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 504.75batch/s, AVG_LOSS=19.4, LOSS_ITER=36.5]
# Epoch 48 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 144.96batch/s, AVG_LOSS=0.481, LOSS_ITER=0.548]
# Epoch 48 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 504.69batch/s, AVG_LOSS=26.1, LOSS_ITER=2.15]
# Epoch 49 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 144.23batch/s, AVG_LOSS=0.472, LOSS_ITER=0.311]
# Epoch 49 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 497.63batch/s, AVG_LOSS=16.9, LOSS_ITER=30.5]
# Epoch 50 train: 100%|███████████████████████████| 240/240 [00:01<00:00, 147.10batch/s, AVG_LOSS=0.465, LOSS_ITER=0.347]
# Epoch 50 val: 100%|███████████████████████████████| 373/373 [00:00<00:00, 507.90batch/s, AVG_LOSS=14.3, LOSS_ITER=30.9]

# %% [markdown]
# ### Train Total Model

# %%
# Training total regression model
loss_list, loss_eval, weight = train_regression(
    model=RegressionNet(cluster=False, n_cluster=N_CLUSTER, num_in=NUM_IN),
    metric=MeanLoss(),
    train_dataloader=train_regression_dataloader,
    valid_dataloader=valid_regression_dataloader,
    weight_path=model_path["total"])

# regr.train_multiple_labels(
#     regr_models,
#     X_train, Y_train[:, :2],
#     X_valid, Y_valid[:, :2],
#     model_path["total"])
# Out:
# Epoch 1 train: 100%|███████████████████████████████| 518/518 [00:18<00:00, 28.65batch/s, AVG_LOSS=20.5, LOSS_ITER=10.9]
# Epoch 1 val: 100%|████████████████████████████████| 820/820 [00:01<00:00, 467.99batch/s, AVG_LOSS=32.6, LOSS_ITER=14.6]
#                                                                                                      Best valid loss: 32.5536
# Epoch 2 train: 100%|███████████████████████████████| 518/518 [00:16<00:00, 30.48batch/s, AVG_LOSS=5.77, LOSS_ITER=4.62]
# Epoch 2 val: 100%|██████████████████████████████████| 820/820 [00:01<00:00, 475.72batch/s, AVG_LOSS=34, LOSS_ITER=13.1]
# Epoch 3 train: 100%|███████████████████████████████| 518/518 [00:17<00:00, 30.35batch/s, AVG_LOSS=4.48, LOSS_ITER=3.84]
# Epoch 3 val: 100%|████████████████████████████████| 820/820 [00:01<00:00, 437.47batch/s, AVG_LOSS=33.9, LOSS_ITER=11.1]
# Epoch 4 train: 100%|███████████████████████████████| 518/518 [00:16<00:00, 30.54batch/s, AVG_LOSS=3.76, LOSS_ITER=2.97]
# Epoch 4 val: 100%|████████████████████████████████| 820/820 [00:01<00:00, 417.24batch/s, AVG_LOSS=33.7, LOSS_ITER=12.6]
# Epoch 5 train: 100%|███████████████████████████████| 518/518 [00:17<00:00, 30.38batch/s, AVG_LOSS=3.35, LOSS_ITER=2.77]
# Epoch 5 val: 100%|████████████████████████████████| 820/820 [00:01<00:00, 437.51batch/s, AVG_LOSS=34.2, LOSS_ITER=13.1]
# Epoch 6 train: 100%|███████████████████████████████| 518/518 [00:17<00:00, 30.34batch/s, AVG_LOSS=3.02, LOSS_ITER=2.19]
# Epoch 6 val: 100%|████████████████████████████████| 820/820 [00:01<00:00, 431.63batch/s, AVG_LOSS=34.3, LOSS_ITER=13.2]
# Epoch 7 train: 100%|███████████████████████████████| 518/518 [00:17<00:00, 30.22batch/s, AVG_LOSS=2.74, LOSS_ITER=1.87]
# Epoch 7 val: 100%|████████████████████████████████| 820/820 [00:01<00:00, 413.86batch/s, AVG_LOSS=34.1, LOSS_ITER=12.8]
# Epoch 8 train: 100%|███████████████████████████████| 518/518 [00:16<00:00, 30.49batch/s, AVG_LOSS=2.57, LOSS_ITER=1.99]
# Epoch 8 val: 100%|██████████████████████████████████| 820/820 [00:01<00:00, 422.14batch/s, AVG_LOSS=33.7, LOSS_ITER=12]
# Epoch 9 train: 100%|███████████████████████████████| 518/518 [00:17<00:00, 30.20batch/s, AVG_LOSS=2.38, LOSS_ITER=1.95]
# Epoch 9 val: 100%|██████████████████████████████████| 820/820 [00:01<00:00, 464.39batch/s, AVG_LOSS=34.4, LOSS_ITER=14]
# Epoch 10 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 30.75batch/s, AVG_LOSS=2.24, LOSS_ITER=2.23]
# Epoch 10 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 453.72batch/s, AVG_LOSS=34.2, LOSS_ITER=12.9]
# Epoch 11 train: 100%|███████████████████████████████| 518/518 [00:17<00:00, 30.28batch/s, AVG_LOSS=2.1, LOSS_ITER=1.64]
# Epoch 11 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 496.18batch/s, AVG_LOSS=34.1, LOSS_ITER=12.8]
# Epoch 12 train: 100%|██████████████████████████████████| 518/518 [00:16<00:00, 30.74batch/s, AVG_LOSS=2, LOSS_ITER=1.8]
# Epoch 12 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 527.92batch/s, AVG_LOSS=34.6, LOSS_ITER=11.2]
# Epoch 13 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 31.14batch/s, AVG_LOSS=1.87, LOSS_ITER=1.74]
# Epoch 13 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 522.29batch/s, AVG_LOSS=34.3, LOSS_ITER=13.7]
# Epoch 14 train: 100%|███████████████████████████████| 518/518 [00:16<00:00, 31.29batch/s, AVG_LOSS=1.8, LOSS_ITER=1.57]
# Epoch 14 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 518.51batch/s, AVG_LOSS=34.6, LOSS_ITER=13.2]
# Epoch 15 train: 100%|███████████████████████████████| 518/518 [00:16<00:00, 30.91batch/s, AVG_LOSS=1.7, LOSS_ITER=1.56]
# Epoch 15 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 516.38batch/s, AVG_LOSS=34.5, LOSS_ITER=12.9]
# Epoch 16 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 31.36batch/s, AVG_LOSS=1.63, LOSS_ITER=1.34]
# Epoch 16 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 519.89batch/s, AVG_LOSS=34.3, LOSS_ITER=12.4]
# Epoch 17 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 31.24batch/s, AVG_LOSS=1.57, LOSS_ITER=1.53]
# Epoch 17 val: 100%|█████████████████████████████████| 820/820 [00:01<00:00, 506.71batch/s, AVG_LOSS=34.4, LOSS_ITER=13]
# Epoch 18 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 31.03batch/s, AVG_LOSS=1.48, LOSS_ITER=1.43]
# Epoch 18 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 504.89batch/s, AVG_LOSS=34.6, LOSS_ITER=11.9]
# Epoch 19 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 30.77batch/s, AVG_LOSS=1.43, LOSS_ITER=1.24]
# Epoch 19 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 514.70batch/s, AVG_LOSS=34.2, LOSS_ITER=12.9]
# Epoch 20 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 30.98batch/s, AVG_LOSS=1.38, LOSS_ITER=1.08]
# Epoch 20 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 495.02batch/s, AVG_LOSS=34.5, LOSS_ITER=13.5]
# Epoch 21 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 31.08batch/s, AVG_LOSS=1.32, LOSS_ITER=1.04]
# Epoch 21 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 523.48batch/s, AVG_LOSS=34.6, LOSS_ITER=13.4]
# Epoch 22 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 30.96batch/s, AVG_LOSS=1.28, LOSS_ITER=1.11]
# Epoch 22 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 516.12batch/s, AVG_LOSS=34.4, LOSS_ITER=13.7]
# Epoch 23 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 30.68batch/s, AVG_LOSS=1.23, LOSS_ITER=0.87]
# Epoch 23 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 527.03batch/s, AVG_LOSS=34.5, LOSS_ITER=13.7]
# Epoch 24 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 30.70batch/s, AVG_LOSS=1.18, LOSS_ITER=1.06]
# Epoch 24 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 511.62batch/s, AVG_LOSS=34.7, LOSS_ITER=14.7]
# Epoch 25 train: 100%|█████████████████████████████| 518/518 [00:16<00:00, 31.34batch/s, AVG_LOSS=1.15, LOSS_ITER=0.807]
# Epoch 25 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 518.35batch/s, AVG_LOSS=34.3, LOSS_ITER=13.3]
# Epoch 26 train: 100%|██████████████████████████████| 518/518 [00:16<00:00, 31.23batch/s, AVG_LOSS=1.1, LOSS_ITER=0.883]
# Epoch 26 val: 100%|█████████████████████████████████| 820/820 [00:01<00:00, 501.19batch/s, AVG_LOSS=34.4, LOSS_ITER=12]
# Epoch 27 train: 100%|█████████████████████████████| 518/518 [00:16<00:00, 31.53batch/s, AVG_LOSS=1.06, LOSS_ITER=0.837]
# Epoch 27 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 506.23batch/s, AVG_LOSS=34.6, LOSS_ITER=11.7]
# Epoch 28 train: 100%|█████████████████████████████| 518/518 [00:16<00:00, 31.23batch/s, AVG_LOSS=1.05, LOSS_ITER=0.834]
# Epoch 28 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 526.03batch/s, AVG_LOSS=34.6, LOSS_ITER=13.6]
# Epoch 29 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 31.44batch/s, AVG_LOSS=0.999, LOSS_ITER=0.738]
# Epoch 29 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 494.39batch/s, AVG_LOSS=34.4, LOSS_ITER=13.5]
# Epoch 30 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 31.47batch/s, AVG_LOSS=0.962, LOSS_ITER=0.679]
# Epoch 30 val: 100%|█████████████████████████████████| 820/820 [00:01<00:00, 503.01batch/s, AVG_LOSS=34.3, LOSS_ITER=13]
# Epoch 31 train: 100%|█████████████████████████████| 518/518 [00:16<00:00, 31.36batch/s, AVG_LOSS=0.951, LOSS_ITER=0.66]
# Epoch 31 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 488.32batch/s, AVG_LOSS=34.4, LOSS_ITER=12.8]
# Epoch 32 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 31.27batch/s, AVG_LOSS=0.907, LOSS_ITER=0.751]
# Epoch 32 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 531.63batch/s, AVG_LOSS=34.6, LOSS_ITER=13.2]
# Epoch 33 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.71batch/s, AVG_LOSS=0.888, LOSS_ITER=0.763]
# Epoch 33 val: 100%|█████████████████████████████████| 820/820 [00:01<00:00, 447.41batch/s, AVG_LOSS=34.5, LOSS_ITER=14]
# Epoch 34 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.65batch/s, AVG_LOSS=0.865, LOSS_ITER=0.561]
# Epoch 34 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 490.05batch/s, AVG_LOSS=34.5, LOSS_ITER=14.1]
# Epoch 35 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.59batch/s, AVG_LOSS=0.827, LOSS_ITER=0.576]
# Epoch 35 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 511.92batch/s, AVG_LOSS=34.6, LOSS_ITER=14.2]
# Epoch 36 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.54batch/s, AVG_LOSS=0.809, LOSS_ITER=0.485]
# Epoch 36 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 498.97batch/s, AVG_LOSS=34.6, LOSS_ITER=13.1]
# Epoch 37 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.59batch/s, AVG_LOSS=0.785, LOSS_ITER=0.476]
# Epoch 37 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 505.77batch/s, AVG_LOSS=34.5, LOSS_ITER=12.9]
# Epoch 38 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.59batch/s, AVG_LOSS=0.761, LOSS_ITER=0.473]
# Epoch 38 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 523.52batch/s, AVG_LOSS=34.5, LOSS_ITER=12.6]
# Epoch 39 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 31.03batch/s, AVG_LOSS=0.751, LOSS_ITER=0.408]
# Epoch 39 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 501.46batch/s, AVG_LOSS=34.5, LOSS_ITER=12.9]
# Epoch 40 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.80batch/s, AVG_LOSS=0.727, LOSS_ITER=0.559]
# Epoch 40 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 487.23batch/s, AVG_LOSS=34.5, LOSS_ITER=12.5]
# Epoch 41 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.85batch/s, AVG_LOSS=0.718, LOSS_ITER=0.507]
# Epoch 41 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 522.00batch/s, AVG_LOSS=34.4, LOSS_ITER=12.6]
# Epoch 42 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 31.29batch/s, AVG_LOSS=0.694, LOSS_ITER=0.416]
# Epoch 42 val: 100%|█████████████████████████████████| 820/820 [00:01<00:00, 512.56batch/s, AVG_LOSS=34.5, LOSS_ITER=12]
# Epoch 43 train: 100%|█████████████████████████████| 518/518 [00:16<00:00, 30.87batch/s, AVG_LOSS=0.677, LOSS_ITER=0.45]
# Epoch 43 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 501.26batch/s, AVG_LOSS=34.5, LOSS_ITER=11.9]
# Epoch 44 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 31.23batch/s, AVG_LOSS=0.662, LOSS_ITER=0.463]
# Epoch 44 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 503.65batch/s, AVG_LOSS=34.5, LOSS_ITER=13.1]
# Epoch 45 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.78batch/s, AVG_LOSS=0.648, LOSS_ITER=0.545]
# Epoch 45 val: 100%|█████████████████████████████████| 820/820 [00:01<00:00, 511.55batch/s, AVG_LOSS=34.4, LOSS_ITER=13]
# Epoch 46 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.62batch/s, AVG_LOSS=0.626, LOSS_ITER=0.424]
# Epoch 46 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 510.94batch/s, AVG_LOSS=34.5, LOSS_ITER=12.8]
# Epoch 47 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.99batch/s, AVG_LOSS=0.615, LOSS_ITER=0.387]
# Epoch 47 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 519.15batch/s, AVG_LOSS=34.5, LOSS_ITER=13.3]
# Epoch 48 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.84batch/s, AVG_LOSS=0.609, LOSS_ITER=0.434]
# Epoch 48 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 493.65batch/s, AVG_LOSS=34.5, LOSS_ITER=12.6]
# Epoch 49 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.72batch/s, AVG_LOSS=0.589, LOSS_ITER=0.344]
# Epoch 49 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 489.49batch/s, AVG_LOSS=34.5, LOSS_ITER=12.1]
# Epoch 50 train: 100%|████████████████████████████| 518/518 [00:16<00:00, 30.69batch/s, AVG_LOSS=0.575, LOSS_ITER=0.346]
# Epoch 50 val: 100%|███████████████████████████████| 820/820 [00:01<00:00, 507.50batch/s, AVG_LOSS=34.5, LOSS_ITER=12.8]

# %% [markdown]
# ### Eval All Regression

# %%
model_evaluation(
    model_total_path=model_path["total"],
    model_dict_path=[
        os.path.join(model_path["ensemble"], "model_0.pth"),
        os.path.join(model_path["ensemble"], "model_1.pth"),
        # os.path.join(model_path["ensemble"], "model_2.pth"),
        # "../../models/uts_models/2023_02_04/ensemble_model/model_2.pth",
    ],
    model_cluster_classifier_path=model_path["cluster_classifier"],
    model_cluster_path=model_path["cluster"],
    metric=MeanLoss(),
    num_in=NUM_IN,
    X_test=X_test,
    Y_test=Y_test[:,:2])

# classic_model_evaluation(
#     model_total_path=model_path["total"],
#     model_dict_path=[
#         os.path.join(model_path["ensemble"], "model_0.sav"),
#         os.path.join(model_path["ensemble"], "model_1.sav"),
#         # os.path.join(model_path["ensemble"], "model_2.sav"),
#         # os.path.join(model_path["ensemble"], "model_3.sav"),
#     ],
#     model_cluster_classifier_path=model_path["cluster_classifier"],
#     model_cluster_path=model_path["cluster"],
#     X_test=X_test,
#     Y_test=Y_test[:, :2])
# Out:
# ===== Load model sklearn successfully =====
# ===== Load model sklearn successfully =====
# Cluster 0 loss:  8.734411003608857
# Cluster 1 loss:  7.506480776688509
# total loss: 8.193235568548602
